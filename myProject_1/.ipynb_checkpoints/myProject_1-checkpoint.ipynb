# %% [markdown]
# ### Задание для курсового проекта
# Метрика: R2 - коэффициент детерминации (sklearn.metrics.r2_score)
#
# Сдача проекта: Сдать проект нужно в течение 7 дней после окончания последнего вебинара.
# Необходимо получить R2 > 0.6 на Private Leaderboard.
#
# * **Примечание:** Все файлы csv должны содержать названия полей (header - то есть "шапку"), разделитель - запятая. В файлах не должны содержаться индексы из датафрейма.

# %% [markdown]
# #### Рекомендации для файла с кодом (ipynb):
#
# 1. Файл должен содержать заголовки и комментарии
# 2. Повторяющиеся операции лучше оформлять в виде функций
# 3. По возможности добавлять графики, описывающие данные (около 3-5)
# 4. Добавлять только лучшую модель, то есть не включать в код все варианты решения проекта
# 5. Скрипт проекта должен отрабатывать от начала и до конца (от загрузки данных до выгрузки предсказаний)
# 6. Весь проект должен быть в одном скрипте (файл ipynb).
# 7. При использовании статистик (среднее, медиана и т.д.) в качестве признаков, лучше считать их на трейне, и потом на валидационных и тестовых данных не считать статистики заново, а брать их с трейна.
# 8. Проект должен полностью отрабатывать за разумное время (не больше 10 минут), поэтому в финальный вариант лучше не включать GridSearch с перебором большого количества сочетаний параметров.

# %% [markdown]
# #### План проекта<a class='anckor' id='plan'>
#
# * [1. Загрузка данных](#load)
# * [2. EDA - разведочный анализ данных](#eda)
#     - анализ целевой переменной
#     - [поиск количественных переменных и их оптимизация](#col)
#         - [датасет для тренировки](#train_col)
#         - [датасет для проверки](#test_col)
#     - [корреляция признаков и анализ их влияния на целевую переменную](#corr)
#     - [поиск пропусков и формирование идей по их ликвидации](#nulls)
#         - [датасет для тренировки](#train_nulls)
#         - [датасет для проверки](#test_nulls)
#     - [поиск выбросов и формирование идей по их ликвидации](#ejection)
#         - [датасет для тренировки](#train_ejection)
#         - [датасет для проверки](#test_ejection)
#     - [поиск категориальных признаков и формирование идей по их кодированию](#cat)
#         - [датасет для тренировки](#train_cat)
#         - [датасет для проверки](#test_cat)
# * [3. Предобработка данных](#preprocessing)
#     - обработка пропусков
#         - [датасет для тренировки](#process_train_nulls)
#         - [датасет для проверки](#process_test_nulls)
#     - [обработка выбросов](#process_ejection)
#         - [датасет для тренировки](#process_train_ejection)
#         - [датасет для проверки](#process_test_ejection)
#     - [генерация новых признаков](#new_cat)
#         - [датасет для тренировки](#new_cat_train)
#         - [датасет для проверки](#new_cat_test)
#     - [разделение датасета на train и test](#separ)
#     - [](#save_dataset)
#     - создание class Preprocessing(dataset) для проекта на основе вышеизложенного
# * [4. Построение моделей](#models)
# * [5. Обучение и валидация моделей](#train)
# * [6. Прогнозирование на тестовом датасете](#test)
# * [7. Предсказание на созданной модели](#prediction)

# %% [markdown]
# ### Подключение библиотек и скриптов

# %%
import numpy as np
import pandas as pd

from scipy.stats import mode

import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Созданные функции

# %%
# Функция для поиска категорийных признаков в датасете
def find_cat(dataset):
    for name in dataset.columns:
        s = ''
        s += name
        if (type(dataset[name][0]) == str):
            s += ' строка,'
        if (dataset[name].nunique() < 4):
            s += ' мало уникальных значений'
        if (s != name):
            print(s)

# %%
# Функция для автоматического уменьшения объёма памати за счёт оптимизации количественных переменных датасета
def reduce_mem_usage(df):
    
    # Определение количество памяти занятой исходным датасетом
    start_mem = df.memory_usage().sum() / 1024**2
    print('Исходным датафреймом использована память в размере: {:.2f} MB'.format(start_mem))
    
    # итерация по признакам (столбцам) датасета
    for col in df.columns:
        col_type = df[col].dtype
        
        # для количественной переменной определяем min и max значения
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            # для целочисленной переменной определяем оптимальный тип и меняем на него у признака
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)  # от -128 до 127 (1 байт)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)  # от -32768 до 32767 (2 байта)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)  # 4 байта
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  # 8 байтов
                    
            # для вещественной переменной определяем оптимальный тип и меняем на него у признака
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)  # 4 байта
                else:
                    df[col] = df[col].astype(np.float64)  # 8 байтов
        else:
            df[col] = df[col].astype('category')

    # Определение количество памяти занятой оптимизированным датасетом
    end_mem = df.memory_usage().sum() / 1024**2
    print('Оптимизированным датафреймом использована память в размере: {:.2f} MB'.format(end_mem))
    print('Использованная датафреймом память уменьшилась на {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df

# %% [markdown]
# #### Пути к директориям и файлам

# %%
TRAIN_DATASET_PATH = './input/real-estate-price-prediction-moscow/train.csv'
PREPARED_DATASET_PATH = './input/real-estate-price-prediction-moscow/train_prepared.csv'
TEST_DATASET_PATH = './input/real-estate-price-prediction-moscow/test.csv'

# %% [markdown]
# ### Описание задачи
#
# Цель - предсказать стоимость дома
#
# Зачем?
#
# _В банках, страховых компаниях:_
# - Узнать истинную стоимость имущества (залога)
# - Принять решение о выдаче ипотеки/страховки
# - Принять решение о % по ипотеке/страховке
#
# _На площадках объявлений (Авито, Циан, ...):_
# - Найти недооцененные квартиры (~ выгодные предложения), показать их пользователям
# - Показывать рыночную стоимость квартиры пользователям
# - Для тех, кто продает квартиру, рекомендовать цену продажи
#
# _Для инвесторов в недвижимость:_
# - Определять рыночную стоимость квартир
# - Поиск недооцененных активов
# - Торговля на рынке недвижимости

# %% [markdown]
# ### Загрузка данных <a class='anchor' id='load'>

# %% [markdown]
# **Считываем данные для тренировки.**
#
# Создаём датафрейм для тренировки train_df из данных файла. По строкам - наблюдения, по столбцам - признаки. Выводим некоторое количество данных. Минимально знакомимся с датафреймом.

# %%
train_df = pd.read_csv(TRAIN_DATASET_PATH, sep=',')
# Считываем данные. 4-е первых строки. 
train_df.head(4)
# Out:
#       Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0  11809          27    3.0  115.027311         NaN           10.0      4
# 1   3013          22    1.0   39.832524   23.169223            8.0      7
# 2   8215           1    3.0   78.342215   47.671972           10.0      2
# 3   2352           1    1.0   40.409907         NaN            1.0     10
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        10.0       2014   0.075424         B         B        11      3097
# 1         8.0       1966   0.118537         B         B        30      6207
# 2        17.0       1988   0.025609         B         B        33      5261
# 3        22.0       1977   0.007122         B         B         1       264
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         0           NaN            0        0       B  305018.871089
# 1         1        1183.0            1        0       B  177734.553407
# 2         0         240.0            3        1       B  282078.720850
# 3         0           NaN            0        1       B  168106.007630

# %% [markdown]
# **Описание датасета**
#
# * **Id** - идентификационный номер квартиры
# * **DistrictId** - идентификационный номер района
# * **Rooms** - количество комнат
# * **Square** - площадь
# * **LifeSquare** - жилая площадь
# * **KitchenSquare** - площадь кухни
# * **Floor** - этаж
# * **HouseFloor** - количество этажей в доме
# * **HouseYear** - год постройки дома
# * **Ecology_1, Ecology_2, Ecology_3** - экологические показатели местности
# * **Social_1, Social_2, Social_3** - социальные показатели местности
# * **Healthcare_1, Helthcare_2** - показатели местности, связанные с охраной здоровья
# * **Shops_1, Shops_2** - показатели, связанные с наличием магазинов, торговых центров
# * **Price** - цена квартиры

# %%
# Считываем данные. 2-е последние строки. 
train_df.tail(2)
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 9998  14561          21    1.0  32.330292   22.326870            5.0      3
# 9999   7202          94    1.0  35.815476   22.301367            6.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 9998         9.0       1969   0.194489         B         B        47
# 9999         9.0       1975   0.127376         B         B        43
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 9998      8004         3         125.0            3        5       B
# 9999      8429         3           NaN            3        9       B
#
#               Price
# 9998  171842.411855
# 9999  177685.627486

# %%
# Считываем данные. Случайная строка. 
train_df.sample()
# Out:
#         Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 5274  4951           9    1.0  40.575412   23.573299           10.0     24
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 5274        22.0       1996   0.069753         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 5274     13670         4           NaN            1       11       B
#
#               Price
# 5274  177202.986207

# %%
train_df.shape
# Out:
# (10000, 20)

# %%
train_df.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
train_df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %% [markdown]
# **Считываем данные для тестирования.**
#
# Создаём датафрейм для тренировки test_df из данных файла. По строкам - наблюдения, по столбцам - признаки. Выводим некоторое количество данных. Минимально знакомимся с датафреймом.

# %%
test_df = pd.read_csv(TEST_DATASET_PATH, sep=',')
# Считываем данные. 4-е первых строки. 
test_df.head()
# Out:
#      Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  4567          44    1.0  36.847630   19.094182            5.0      5
# 1  5925          62    1.0  42.493907   42.568133           10.0      7
# 2   960          27    2.0  59.463678         NaN            9.0     19
# 3  3848          23    3.0  49.646030   33.893825            6.0      2
# 4   746          74    1.0  53.837056         NaN            1.0      8
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1970   0.036122         B         B        24      4378
# 1        17.0       2017   0.072158         B         B         2       629
# 2        19.0       1977   0.211401         B         B         9      1892
# 3         2.0       1965   0.014073         B         B         2       475
# 4        17.0       1977   0.309479         B         B        35      7715
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         0        1036.0            1        1       B
# 1         1           NaN            0        0       A
# 2         0           NaN            0        1       B
# 3         0           NaN            0        0       B
# 4         4         990.0            0        6       B

# %%
test_df.shape
# Out:
# (5000, 19)

# %%
test_df.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2'],
#       dtype='object')

# %%
train_df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ## 1. EDA  - исследовательский (разведочный) анализ данных<a class='anckor' id='eda'>
#
# * анализ целевой переменной:
#     - регрессия - распределение, меры центральной тенденции
#     - классификация - баланс классов
# * анализ признаков в датасете:
#     - поиск количественных признаков и их оптимизация
#     - корреляция признаков и анализ влияния на целевую переменную
#     - поиск проблемных признаков
#     - поиск пропусков и формирование идей по их ликвидации
#     - поиск выбросов и формирование идей по их ликвидации
# * анализ категориальных признаков:
#     - поиск категориальных признаков их анализ
#     - формирование идей по их кодированию
# * формирование идей для новых признаков

# %% [markdown]
# ### Анализ целевой переменной
#
# Проводим анализ целевого признака 'Price'. Предварительный анализ целевой переменной показал, что она является количественной, непрерывной и вещественной. Создадим диаграмму распределения (регрессии) целевой переменной.

# %%
plt.figure(figsize = (16, 8))

train_df['Price'].hist(bins=30)
plt.ylabel('Count')
plt.xlabel('Price')

plt.title('Диаграмма распределения стоимости квартир (Частота целевого параметра в train_df)')
plt.show()

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Анализ признаков

# %% [markdown]
# ### Количественные переменные<a class='anckor' id='col'>
#
# #### Приведение типов данных для датасета train_df<a class='anckor' id='train_col'>
#
# Проводим анализ количественных признаков, приводим к оптимальному типу.

# %%
train_df.describe()
# Out:
#                 Id    DistrictId         Rooms        Square   LifeSquare  \
# count  10000.00000  10000.000000  10000.000000  10000.000000  7887.000000
# mean    8383.40770     50.400800      1.890500     56.315775    37.199645
# std     4859.01902     43.587592      0.839512     21.058732    86.241209
# min        0.00000      0.000000      0.000000      1.136859     0.370619
# 25%     4169.50000     20.000000      1.000000     41.774881    22.769832
# 50%     8394.50000     36.000000      2.000000     52.513310    32.781260
# 75%    12592.50000     75.000000      2.000000     65.900625    45.128803
# max    16798.00000    209.000000     19.000000    641.065193  7480.592129
#
#        KitchenSquare         Floor    HouseFloor     HouseYear     Ecology_1  \
# count   10000.000000  10000.000000  10000.000000  1.000000e+04  10000.000000
# mean        6.273300      8.526700     12.609400  3.990166e+03      0.118858
# std        28.560917      5.241148      6.775974  2.005003e+05      0.119025
# min         0.000000      1.000000      0.000000  1.910000e+03      0.000000
# 25%         1.000000      4.000000      9.000000  1.974000e+03      0.017647
# 50%         6.000000      7.000000     13.000000  1.977000e+03      0.075424
# 75%         9.000000     12.000000     17.000000  2.001000e+03      0.195781
# max      2014.000000     42.000000    117.000000  2.005201e+07      0.521867
#
#            Social_1      Social_2      Social_3  Healthcare_1   Helthcare_2  \
# count  10000.000000  10000.000000  10000.000000   5202.000000  10000.000000
# mean      24.687000   5352.157400      8.039200   1142.904460      1.319500
# std       17.532614   4006.799803     23.831875   1021.517264      1.493601
# min        0.000000    168.000000      0.000000      0.000000      0.000000
# 25%        6.000000   1564.000000      0.000000    350.000000      0.000000
# 50%       25.000000   5285.000000      2.000000    900.000000      1.000000
# 75%       36.000000   7227.000000      5.000000   1548.000000      2.000000
# max       74.000000  19083.000000    141.000000   4849.000000      6.000000
#
#             Shops_1          Price
# count  10000.000000   10000.000000
# mean       4.231300  214138.857399
# std        4.806341   92872.293865
# min        0.000000   59174.778028
# 25%        1.000000  153872.633942
# 50%        3.000000  192269.644879
# 75%        6.000000  249135.462171
# max       23.000000  633233.466570

# %%
train_df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %% [markdown]
# Приводим данные признаков:
#
# - 'Id' и 'DistrictId' к строковому типу;
# - 'Rooms', 'Floor', 'HouseFloor', 'HouseYear', 'Social_1', 'Social_2', 'Social_3', 'Helthcare_2', 'Shops_1' к типу int32;
# - 'Square', 'LifeSquare', 'KitchenSquare', 'Ecology_1', 'Healthcare_1' к типу float32.

# %%
train_df['Id'] = train_df['Id'].astype(str)
train_df['DistrictId'] = train_df['DistrictId'].astype(str)
train_df = train_df.astype({'Rooms': np.int32, 'Floor': np.int32, 'Shops_1': np.int32,
                            'HouseFloor': np.int32, 'HouseYear': np.int32, 
                            'Social_1': np.int32, 'Social_2': np.int32, 
                            'Social_3': np.int32, 'Helthcare_2': np.int32,
                            'Square': np.float32, 'LifeSquare': np.float32, 'KitchenSquare': np.float32, 
                            'Ecology_1': np.float32, 'Healthcare_1': np.float32})
train_df.dtypes
# Out:
# Id                object
# DistrictId        object
# Rooms              int32
# Square           float32
# LifeSquare       float32
# KitchenSquare    float32
# Floor              int32
# HouseFloor         int32
# HouseYear          int32
# Ecology_1        float32
# Ecology_2         object
# Ecology_3         object
# Social_1           int32
# Social_2           int32
# Social_3           int32
# Healthcare_1     float32
# Helthcare_2        int32
# Shops_1            int32
# Shops_2           object
# Price            float64
# dtype: object

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# #### Приведение типов данных для датасета test_df<a class='anckor' id='test_col'>
#
# Проводим анализ количественных признаков, приводим к оптимальному типу.

# %%
test_df.describe()
# Out:
#                  Id   DistrictId        Rooms       Square   LifeSquare  \
# count   5000.000000  5000.000000  5000.000000  5000.000000  3959.000000
# mean    8412.595400    51.279200     1.910000    56.449500    36.158810
# std     4832.674037    44.179466     0.838594    19.092787    17.825287
# min        1.000000     0.000000     0.000000     1.378543     0.333490
# 25%     4221.750000    21.000000     1.000000    41.906231    23.092026
# 50%     8320.500000    37.000000     2.000000    52.921340    32.925087
# 75%    12598.250000    77.000000     2.000000    66.285129    45.174091
# max    16795.000000   212.000000    17.000000   223.453689   303.071094
#
#        KitchenSquare        Floor   HouseFloor    HouseYear    Ecology_1  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean        5.976800     8.632000    12.601000  1984.392600     0.119874
# std         9.950018     5.483228     6.789213    18.573149     0.120070
# min         0.000000     1.000000     0.000000  1908.000000     0.000000
# 25%         1.000000     4.000000     9.000000  1973.000000     0.019509
# 50%         6.000000     7.000000    12.000000  1977.000000     0.072158
# 75%         9.000000    12.000000    17.000000  2000.000000     0.195781
# max       620.000000    78.000000    99.000000  2020.000000     0.521867
#
#           Social_1      Social_2     Social_3  Healthcare_1  Helthcare_2  \
# count  5000.000000   5000.000000  5000.000000   2623.000000   5000.00000
# mean     24.933800   5406.900000     8.262600   1146.657263      1.31940
# std      17.532202   4026.614773    23.863762   1044.744231      1.47994
# min       0.000000    168.000000     0.000000      0.000000      0.00000
# 25%       6.000000   1564.000000     0.000000    325.000000      0.00000
# 50%      25.000000   5285.000000     2.000000    900.000000      1.00000
# 75%      36.000000   7287.000000     5.000000   1548.000000      2.00000
# max      74.000000  19083.000000   141.000000   4849.000000      6.00000
#
#            Shops_1
# count  5000.000000
# mean      4.242800
# std       4.777365
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       6.000000
# max      23.000000

# %%
test_df.dtypes
# Out:
# Id                 int64
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# dtype: object

# %%
test_df['Id'] = test_df['Id'].astype(str)
test_df['DistrictId'] = test_df['DistrictId'].astype(str)
test_df = test_df.astype({'Rooms': np.int32, 'Floor': np.int32, 'Shops_1': np.int32,
                            'HouseFloor': np.int32, 'HouseYear': np.int32, 
                            'Social_1': np.int32, 'Social_2': np.int32, 
                            'Social_3': np.int32, 'Helthcare_2': np.int32,
                            'Square': np.float32, 'LifeSquare': np.float32, 'KitchenSquare': np.float32, 
                            'Ecology_1': np.float32, 'Healthcare_1': np.float32})
test_df.dtypes
# Out:
# Id                object
# DistrictId        object
# Rooms              int32
# Square           float32
# LifeSquare       float32
# KitchenSquare    float32
# Floor              int32
# HouseFloor         int32
# HouseYear          int32
# Ecology_1        float32
# Ecology_2         object
# Ecology_3         object
# Social_1           int32
# Social_2           int32
# Social_3           int32
# Healthcare_1     float32
# Helthcare_2        int32
# Shops_1            int32
# Shops_2           object
# dtype: object

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Корреляция признаков и анализ их влияния на целевую переменную<a class='anckor' id='corr'>
#
# Корреляция независимых переменных с независимой (целевой) переменной. Сильной корреляция, когда значение приближается к 1 или −1, и о ее отсутствие, когда значение близко к нулю. Анализ корреляционной матрицы позволяет сделать вывод о взаимосвязи переменных.

# %%
# посчитаем коэффициент корреляции для всего датафрейма и округлим значение
corr_matrix = train_df.corr().round(2)
corr_matrix
# Out:
#                Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Rooms           1.00    0.66        0.13           0.01  -0.00       -0.03
# Square          0.66    1.00        0.20           0.01   0.11        0.08
# LifeSquare      0.13    0.20        1.00          -0.00   0.02        0.03
# KitchenSquare   0.01    0.01       -0.00           1.00  -0.01        0.00
# Floor          -0.00    0.11        0.02          -0.01   1.00        0.42
# HouseFloor     -0.03    0.08        0.03           0.00   0.42        1.00
# HouseYear      -0.01   -0.01       -0.00           0.00   0.00       -0.00
# Ecology_1      -0.03   -0.06       -0.02          -0.01  -0.02       -0.00
# Social_1        0.08   -0.07       -0.05           0.04  -0.04       -0.02
# Social_2        0.07   -0.04       -0.04           0.04  -0.02        0.01
# Social_3        0.01    0.04        0.01          -0.02  -0.00       -0.01
# Healthcare_1    0.04   -0.04       -0.03           0.01  -0.14       -0.14
# Helthcare_2     0.06   -0.02       -0.02           0.04  -0.07       -0.07
# Shops_1         0.05    0.02       -0.01           0.01   0.02        0.03
# Price           0.55    0.52        0.08           0.03   0.13        0.09
#
#                HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms              -0.01      -0.03      0.08      0.07      0.01
# Square             -0.01      -0.06     -0.07     -0.04      0.04
# LifeSquare         -0.00      -0.02     -0.05     -0.04      0.01
# KitchenSquare       0.00      -0.01      0.04      0.04     -0.02
# Floor               0.00      -0.02     -0.04     -0.02     -0.00
# HouseFloor         -0.00      -0.00     -0.02      0.01     -0.01
# HouseYear           1.00       0.00      0.00      0.00      0.00
# Ecology_1           0.00       1.00      0.03      0.01     -0.12
# Social_1            0.00       0.03      1.00      0.96      0.02
# Social_2            0.00       0.01      0.96      1.00      0.07
# Social_3            0.00      -0.12      0.02      0.07      1.00
# Healthcare_1       -0.01      -0.04      0.08      0.05      0.13
# Helthcare_2         0.01       0.03      0.52      0.47      0.29
# Shops_1             0.00      -0.08      0.53      0.56      0.66
# Price               0.00      -0.06      0.26      0.24      0.07
#
#                Healthcare_1  Helthcare_2  Shops_1  Price
# Rooms                  0.04         0.06     0.05   0.55
# Square                -0.04        -0.02     0.02   0.52
# LifeSquare            -0.03        -0.02    -0.01   0.08
# KitchenSquare          0.01         0.04     0.01   0.03
# Floor                 -0.14        -0.07     0.02   0.13
# HouseFloor            -0.14        -0.07     0.03   0.09
# HouseYear             -0.01         0.01     0.00   0.00
# Ecology_1             -0.04         0.03    -0.08  -0.06
# Social_1               0.08         0.52     0.53   0.26
# Social_2               0.05         0.47     0.56   0.24
# Social_3               0.13         0.29     0.66   0.07
# Healthcare_1           1.00         0.20     0.06   0.14
# Helthcare_2            0.20         1.00     0.47   0.25
# Shops_1                0.06         0.47     1.00   0.18
# Price                  0.14         0.25     0.18   1.00

# %% [markdown]
# Из корреляционной матрицы видно, что:
# - умеренная корреляция наблюдается у переменных: Rooms, Square;
# - слабая корреляция у переменных: Social_1, Social_2, Helthcare_2, Shops_1, Healthcare_1, Floor;
# - очень слабая или отсутствует у переменных: LifeSquare, KitchenSquare, HouseFloor, HouseYear, Ecology_1, Social_3.
#
#
# **Вывод:**
#
#    - необходимо провести анализ переменных с умеренной корреляцией **Rooms** и **Square** на предмет пропусков и выбросов;
#    - для переменных со слабой корреляцией **HouseFloor** и **HouseYear** тоже необходимо провести анализ на предмет пропусков и выбросов, т.к. они могут влиять на стоимость квартиры сильнее при устранении ошибок;
#    - переменные с очень слабой корреляцией можно из датасета удалить.

# %% [markdown]
# Покажем диаграммы рассеяния переменных с умеренной корреляцией.

# %%
# подготовим данные (поместим столбцы датафрейма в переменные)
x1 = train_df['Rooms']
x2 = train_df['Square']
y = train_df['Price']

# %%
# зададим размер и построим первый график
plt.figure(figsize = (10,6))
#plt.yscale(value="log")
plt.scatter(x1, y)
 
plt.xlabel('Количество комнат', fontsize = 15)
plt.ylabel('Цена квартиры', fontsize = 15)
plt.title('Количество комнат и цены на квартиры', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Количество комнат и цены на квартиры')

# %%
# зададим размер и построим второй график
plt.figure(figsize = (10,6))
#plt.yscale(value="log")
plt.scatter(x2, y)
 
plt.xlabel('Общая площадь', fontsize = 15)
plt.ylabel('Цена квартиры', fontsize = 15)
plt.title('Общая площадь и цены на квартиры', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'Общая площадь и цены на квартиры')

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Поиск пропусков и формирование идей по их ликвидации<a class='anckor' id='nulls'>
#
# #### Поиск пропусков в датасете train_df<a class='anckor' id='train_nulls'>
#
#     вывод концентрации пропусков в процентах для каждого признака (если пропусков у признака > 70%, то такой признак удаляем

# %%
train_df.isna().sum()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %%
# Концентрация пропусков в процентах в датасете
train_df.isnull().mean() * 100
# Out:
# Id                0.00
# DistrictId        0.00
# Rooms             0.00
# Square            0.00
# LifeSquare       21.13
# KitchenSquare     0.00
# Floor             0.00
# HouseFloor        0.00
# HouseYear         0.00
# Ecology_1         0.00
# Ecology_2         0.00
# Ecology_3         0.00
# Social_1          0.00
# Social_2          0.00
# Social_3          0.00
# Healthcare_1     47.98
# Helthcare_2       0.00
# Shops_1           0.00
# Shops_2           0.00
# Price             0.00
# dtype: float64

# %% [markdown]
# Переменная LifeSquare, имеющая 21,13% пропусков, согласно корреляционной матрицы на целевую переменную влияние не имеет. В связи с этим мы не будем обрабатывать пропуска, а удалим этот признак.
#
# Переменная Healthcare_1, имеющая 47.98% пропусков, согласно корреляционной матрицы на целевую переменную имеет слабое влияние. В связи с этим мы заменим пропуски на минимальное значение = 0, что может усилить влияние на целевую переменную.

# %% [markdown]
# #### Поиск пропусков в датасете test_df<a class='anckor' id='test_nulls'>
#
# вывод концентрации пропусков в процентах для каждого признака (если пропусков у признака > 70%, то такой признак удаляем

# %%
test_df.isna().sum()
# Out:
# Id                  0
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       1041
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     2377
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# dtype: int64

# %%
# Концентрация пропусков в процентах в датасете
test_df.isnull().mean() * 100
# Out:
# Id                0.00
# DistrictId        0.00
# Rooms             0.00
# Square            0.00
# LifeSquare       20.82
# KitchenSquare     0.00
# Floor             0.00
# HouseFloor        0.00
# HouseYear         0.00
# Ecology_1         0.00
# Ecology_2         0.00
# Ecology_3         0.00
# Social_1          0.00
# Social_2          0.00
# Social_3          0.00
# Healthcare_1     47.54
# Helthcare_2       0.00
# Shops_1           0.00
# Shops_2           0.00
# dtype: float64

# %% [markdown]
# Переменная LifeSquare, имеющая 20.82% пропусков, согласно корреляционной матрицы на целевую переменную влияние не имеет. В связи с этим мы не будем обрабатывать пропуска, а удалим этот признак.
#
# Переменная Healthcare_1, имеющая 47.54% пропусков, согласно корреляционной матрицы на целевую переменную имеет слабое влияние. В связи с этим мы заменим пропуски на минимальное значение = 0, что может усилить влияние на целевую переменную.

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Поиск выбросов и формирование идей по их ликвидации<a class='anckor' id='ejection'>
#
# #### Обнаружение выбросов в количественных переменных датасета train_df<a class='anckor' id='train_ejection'>

# %%
train_df.describe().round(3)
# Out:
#           Rooms     Square  LifeSquare  KitchenSquare      Floor  HouseFloor  \
# count  10000.00  10000.000    7887.000      10000.000  10000.000   10000.000
# mean       1.89     56.316      37.200          6.273      8.527      12.609
# std        0.84     21.059      86.241         28.561      5.241       6.776
# min        0.00      1.137       0.371          0.000      1.000       0.000
# 25%        1.00     41.775      22.770          1.000      4.000       9.000
# 50%        2.00     52.513      32.781          6.000      7.000      13.000
# 75%        2.00     65.901      45.129          9.000     12.000      17.000
# max       19.00    641.065    7480.592       2014.000     42.000     117.000
#
#           HouseYear  Ecology_1   Social_1   Social_2   Social_3  Healthcare_1  \
# count  1.000000e+04  10000.000  10000.000  10000.000  10000.000      5202.000
# mean   3.990166e+03      0.119     24.687   5352.157      8.039      1142.904
# std    2.005003e+05      0.119     17.533   4006.800     23.832      1021.519
# min    1.910000e+03      0.000      0.000    168.000      0.000         0.000
# 25%    1.974000e+03      0.018      6.000   1564.000      0.000       350.000
# 50%    1.977000e+03      0.075     25.000   5285.000      2.000       900.000
# 75%    2.001000e+03      0.196     36.000   7227.000      5.000      1548.000
# max    2.005201e+07      0.522     74.000  19083.000    141.000      4849.000
#
#        Helthcare_2    Shops_1       Price
# count    10000.000  10000.000   10000.000
# mean         1.320      4.231  214138.857
# std          1.494      4.806   92872.294
# min          0.000      0.000   59174.778
# 25%          0.000      1.000  153872.634
# 50%          1.000      3.000  192269.645
# 75%          2.000      6.000  249135.462
# max          6.000     23.000  633233.467

# %% [markdown]
# Предварительная оценка признаков на выбросы с помощью метода describe().
# * Rooms - имеет выброс по минимальному значению, т.к. количество комнат должно быть 1 и более;
# * Square - имеет выброс по минимальному значению, т.к. общая площадь должна быть 10 и более;
# * LifeSquare - имеет выброс по минимальному и максимальному значениям, т.к. жилая площадь должна быть 10 и более и не должна быть больше общей площади;
# * KitchenSquare - имеет выброс по минимальному и максимальному значениям, т.к. площадь кухни должна быть 4 и более и не должна быть больше общей площади;
# * HouseFloor - имеет выброс по минимальному значению, т.к. количество этажей в доме должно быть 1 и более;
# * HouseYear - имеет выброс по максимальному значению, т.к. год постройки дома не должен превышать 2020;
# * Floor, Ecology_1, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Price - не имеют выбросы
#
# Проведём более подробную оценку выбросов для признаков: **Rooms, Square, HouseFloor, HouseYear.**
#
# Для признаков: **LifeSquare, KitchenSquare** можно не проводить подробную оценку выбросов, т.к. эти признаки имеют очень слабую корреляцию с целевой переменной и их в дальнейшем мы не будем учитывать.

# %%
# Строим гистограмму для обнаружения выбросов у признака Rooms
train_df['Rooms'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
# Строим коробчатую диаграмму для обнаружения выбросов у признака Rooms
train_df.boxplot(column=['Rooms'])
# Out:
# <AxesSubplot:>

# %%
train_df['Rooms'].value_counts()
# Out:
# 2     3880
# 1     3705
# 3     2235
# 4      150
# 5       18
# 0        8
# 10       2
# 19       1
# 6        1
# Name: Rooms, dtype: int64

# %%
train_df[train_df['Rooms'] > 5]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 2004   5927         57     10  59.056976   36.223072           10.0     22
# 2728  14865          9     10  60.871265   38.420681           10.0      3
# 6088   8491          1     19  42.006046   21.779287            7.0     17
# 8794  14003         99      6  59.414333   38.702244            6.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 2004          22       2002   0.090799         B         B        74
# 2728           2       1994   0.161532         B         B        25
# 6088          17       2014   0.007122         B         B         1
# 8794           9       1969   0.033494         B         B        66
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 2004     19083         2           NaN            5       15       B
# 2728      5648         1          30.0            2        4       B
# 6088       264         0           NaN            0        1       B
# 8794     10573         1        1322.0            3        8       B
#
#               Price
# 2004  317265.323792
# 2728  172329.270863
# 6088   78364.616704
# 8794  229661.964416

# %% [markdown]
# Переменная Rooms оказывает умеренное влияние на целевую переменную, в связи с этим выброс = 0 заменим на значения согласно логике:
#
# - Rooms = 1 - для Square < 38;
# - Rooms = 2 - для Square >= 38 & Square < 65;
# - Rooms = 3 - для Square >= 65 & Square < 90;
# - Rooms = 4 - для Square >= 90 & Square < 120;
# - Rooms = Square // 25 - для Square > 65
#
# Выбросы с Rooms > 5 удалим из датасета, т.к. они имеют все признаки ошибочной записи и выпадают из структуры датасета.

# %%
train_df['Square'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
train_df.boxplot(column=['Square'])
# Out:
# <AxesSubplot:>

# %%
train_df[train_df['Square'] < 10]
# Out:
#          Id DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 161    6782         45      1  2.954309    5.257278            1.0      3
# 328    4504         27      3  4.390331    5.610772            1.0      8
# 1401   9487          5      1  5.129221    5.549458            1.0      1
# 4496  15744         34      1  1.988943    2.642219            1.0     21
# 4800   7657         38      1  4.502784    4.618547            1.0     28
# 5009  11526         27      1  4.633498    1.969969            1.0     18
# 7033   1748         88      2  5.497061   67.628716            1.0     24
# 7470  14786          1      1  1.136859    4.525736            1.0      3
# 8572  10202          6      1  2.596351    4.604943            1.0      3
# 8805  10527         27      1  4.380726   40.805836            1.0     10
# 9067  13265          1      3  4.823679   79.767967            0.0      6
# 9869   3224         27      0  2.377248    0.873147            0.0      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 161            1       1977   0.195781         B         B        23
# 328           19       2016   0.211401         B         B         9
# 1401           1       1977   0.150818         B         B        16
# 4496           4       1977   0.069753         B         B        53
# 4800           1       1977   0.060753         B         B        15
# 5009           1       1977   0.011654         B         B         4
# 7033          22       1977   0.127376         B         B        43
# 7470           1       1977   0.007122         B         B         1
# 8572          25       2014   0.243205         B         B         5
# 8805          17       2013   0.211401         B         B         9
# 9067          17       1977   0.007122         B         B         1
# 9869           0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 161       5212         6           NaN            3        2       B
# 328       1892         0           NaN            0        1       B
# 1401      3433         4        2643.0            4        5       B
# 4496     13670         4           NaN            1       11       B
# 4800      2787         2         520.0            0        7       B
# 5009       915         0           NaN            0        0       B
# 7033      8429         3           NaN            3        9       B
# 7470       264         0           NaN            0        1       B
# 8572      1564         0         540.0            0        0       B
# 8805      1892         0           NaN            0        1       B
# 9067       264         0           NaN            0        1       B
# 9869       469         0           NaN            0        0       B
#
#               Price
# 161   438005.182323
# 328   161379.067034
# 1401  369472.403061
# 4496  458378.777006
# 4800  483283.488083
# 5009  107604.269441
# 7033  412511.088764
# 7470  181434.825589
# 8572  137597.601458
# 8805   97560.720383
# 9067  237716.681261
# 9869  126596.941798

# %%
train_df[train_df['Square'] > 300]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 726      28          9      2  604.705994         NaN            1.0     17
# 7010   2307        102      1  409.425171  410.639740           10.0      4
# 9229  11602         30      2  641.065186  638.163208           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 726           18       1977   0.161532         B         B        25
# 7010           4       2016   0.238617         B         B        26
# 9229          19       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 726       5648         1          30.0            2        4       B
# 7010      3889         6         705.0            3        6       B
# 9229      6398       141        1046.0            3       23       B
#
#               Price
# 726   187717.242538
# 7010   90470.430830
# 9229  133529.681562

# %% [markdown]
# Переменная Square оказывает умеренное влияние на целевую переменную, в связи с этим выброс < 10 заменим на значения согласно логике:
#
# - Square = среднее значение Square для однотипных квартир.
#
# Выбросы с Square > 300 удалим из датасета, т.к. они имеют все признаки ошибочной записи и выпадают из структуры датасета.
#
# После исправления выбросов для переменных Rooms и Square необходимо провести анализ соответствия этих переменных друг другу, т.к. они тесно связаны между собой, и исправить несоответствие.

# %%
train_df['KitchenSquare'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
train_df.boxplot(column='KitchenSquare')
# Out:
# <AxesSubplot:>

# %%
train_df[train_df['KitchenSquare'] < 5]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3      2352          1      1  40.409908         NaN            1.0     10
# 8      9951          1      1  46.887894   44.628132            1.0     12
# 9      8094          6      3  79.867477   75.085129            1.0      3
# 18     4581          1      1  47.582481         NaN            1.0     16
# 19      367         45      1  42.367290   40.012527            1.0     16
# ...     ...        ...    ...        ...         ...            ...    ...
# 9982  10268         27      1  36.112392    1.855415            1.0      9
# 9983    647          1      2  63.324024         NaN            1.0      4
# 9990  10635         21      1  18.983963   11.419796            2.0      1
# 9991  11173          6      2  62.648777         NaN            0.0      6
# 9993   9289          1      3  84.486076   88.931511            0.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3             22       1977   0.007122         B         B         1
# 8             20       1977   0.007122         B         B         1
# 9             17       2014   0.243205         B         B         5
# 18            16       1977   0.007122         B         B         1
# 19            14       2015   0.195781         B         B        23
# ...          ...        ...        ...       ...       ...       ...
# 9982          16       1977   0.211401         B         B         9
# 9983          17       1977   0.007122         B         B         1
# 9990           5       1967   0.194489         B         B        47
# 9991          17       1977   0.243205         B         B         5
# 9993          22       2016   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 3          264         0           NaN            0        1       B
# 8          264         0           NaN            0        1       B
# 9         1564         0         540.0            0        0       B
# 18         264         0           NaN            0        1       B
# 19        5212         6           NaN            3        2       B
# ...        ...       ...           ...          ...      ...     ...
# 9982      1892         0           NaN            0        1       B
# 9983       264         0           NaN            0        1       B
# 9990      8004         3         125.0            3        5       B
# 9991      1564         0         540.0            0        0       B
# 9993       264         0           NaN            0        1       B
#
#               Price
# 3     168106.007630
# 8     160400.401732
# 9     194756.023945
# 18    128803.593810
# 19    250466.980777
# ...             ...
# 9982   94881.691800
# 9983  183809.327114
# 9990  112411.221700
# 9991  182625.548872
# 9993  264213.558631
#
# [3222 rows x 20 columns]

# %%
train_df[train_df['KitchenSquare'] > 25]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 286    2737         27      3  123.430069  125.806984          123.0      5
# 456   10546         62      1   46.013187   43.417042           43.0      4
# 511    8685         62      5  124.933289   81.122368           30.0      5
# 682   16593         52      2   64.859245         NaN           62.0     15
# 755   15781         10      1   35.813564   19.953993           35.0      6
# 1614   3267         58      3  138.980820  138.004593           43.0      2
# 1728  16395          2      3   79.722244   44.731220           72.0     12
# 1906   5548         86      5  275.645294  233.949310           26.0     12
# 2108   2271         27      1   43.292515   42.835644           40.0     12
# 2325   7111         27      2  139.070297   89.787666           42.0      5
# 2454  12390         72      3   97.490677   99.323555           96.0     22
# 2632    300         31      2  106.427689   34.230415           32.0      4
# 2702   1315          6      1   48.128113   45.023533           48.0     21
# 2785   6569         27      1   38.220257   18.716856           84.0      4
# 2790  15947        129      4  185.906403   84.830078           31.0      5
# 2831  12507         54      2   79.810532   79.578964           78.0     10
# 3125   8500         31      1   80.606247   25.299591           29.0      6
# 3228   6708         48      1   42.069359   22.487740           39.0      1
# 3240   2371         27      2   68.841072   64.234955           66.0      4
# 3586  12918         23      2   51.440464   53.134243           51.0      3
# 3725    299         27      2   66.787521   64.616661           60.0     14
# 3956   4966         96      3   78.445679   47.146755           75.0      9
# 4091  15466         88      1   42.357487   44.779713           41.0     10
# 5002   7441         62      3  114.734474  112.589081          112.0      3
# 5033  16781         27      1   36.138409   36.710541           36.0     19
# 5273  13703         42      1   38.071693   19.723547           73.0      9
# 5663  11739         27      2   61.070297   59.845093           58.0      8
# 5695  11624         46      1   42.983284   24.224436           37.0     15
# 5746  12074         94      3  108.957283   51.063721           27.0      2
# 5764   6674         54      1  168.086349  125.486565           30.0     18
# 5792   6508         23      2   67.146049   33.959152           63.0      5
# 6079    448         48      1   41.186905    1.626502           41.0      2
# 6293    673         27      1   54.418213   51.498581           51.0     10
# 6505  14679         81      1   32.276665   19.278395         1970.0      6
# 7080   4265        161      2   53.216778   32.644859           53.0      7
# 7601  12666         34      2   60.603363    2.400832           58.0     14
# 7733  12552         58      3  116.405693  113.109650          112.0      3
# 8011   3233        129      4  186.692596   87.487083           32.0      3
# 8329   7162         34      2   56.738762   57.510395           54.0     26
# 8855   9690         27      1   40.081043   37.834965           37.0     18
# 9520  14656         62      1   47.100719   46.447960         2014.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 286           10       2015   0.017647         B         B         2
# 456           17       2019   0.072158         B         B         2
# 511            3       2017   0.072158         B         B         2
# 682           17       1977   0.371149         B         B        34
# 755           14       1971   0.282798         B         B        33
# 1614           2       1977   0.437885         B         B        23
# 1728          16       1987   0.130618         B         B        39
# 1906          37       2011   0.161976         B         A        31
# 2108          11       2015   0.211401         B         B         9
# 2325           3       2016   0.014073         B         B         2
# 2454          25       2019   0.210473         B         B        11
# 2632          40       2013   0.151346         B         A        32
# 2702           1       2013   0.243205         B         B         5
# 2785          17       2018   0.011654         B         B         4
# 2790           3       2015   0.020741         B         B        24
# 2831          15       2014   0.006076         B         B        30
# 3125          40       2014   0.151346         B         A        32
# 3228          10       2010   0.041125         B         B        46
# 3240           2       2014   0.017647         B         B         2
# 3586          17       2017   0.005767         B         B         1
# 3725          20       2015   0.017647         B         B         2
# 3956          12       1977   0.041116         B         B        53
# 4091          19       2016   0.127376         B         B        43
# 5002           3       2015   0.072158         B         B         2
# 5033          19       2017   0.072158         B         B         2
# 5273          10       2006   0.158249         B         B        21
# 5663          17       2016   0.072158         B         B         2
# 5695          16       1983   0.188784         B         B        31
# 5746          22       2008   0.282798         B         B        33
# 5764          28       2011   0.006076         B         B        30
# 5792          17       2019   0.034656         B         B         0
# 6079           1       1977   0.041125         B         B        46
# 6293          17       2017   0.072158         B         B         2
# 6505           1       1977   0.006076         B         B        30
# 7080          17       1994   0.000699         B         B        14
# 7601          22       1977   0.069753         B         B        53
# 7733           3       2016   0.437885         B         B        23
# 8011           3       2011   0.020741         B         B        24
# 8329          25       2016   0.069753         B         B        53
# 8855          19       2019   0.211401         B         B         9
# 9520           1       2014   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 286        469         0           NaN            0        0       B
# 456        629         1           NaN            0        0       A
# 511        629         1           NaN            0        0       A
# 682       7065         1         750.0            2        5       B
# 755       8667         2           NaN            0        6       B
# 1614      5735         3        1084.0            0        5       B
# 1728     10418         9         900.0            1        9       B
# 1906      7010         5        4508.0            3        7       B
# 2108      1892         0           NaN            0        1       B
# 2325       475         0           NaN            0        0       B
# 2454      2398         2        1994.0            3        0       B
# 2632      5889        10         830.0            4        1       B
# 2702      1564         0         540.0            0        0       B
# 2785       915         0           NaN            0        0       B
# 2790      5613         5        1340.0            2        5       B
# 2831      5285         0         645.0            6        6       B
# 3125      5889        10         830.0            4        1       B
# 3228      9515         5           NaN            1       10       B
# 3240       469         0           NaN            0        0       B
# 3586       388         0           NaN            0        0       B
# 3725       469         0           NaN            0        0       B
# 3956     14892         4           NaN            1        4       B
# 4091      8429         3           NaN            3        9       B
# 5002       629         1           NaN            0        0       A
# 5033       629         1           NaN            0        0       A
# 5273      5731         0           NaN            1        0       B
# 5663       629         1           NaN            0        0       A
# 5695      6137         4           NaN            0        1       B
# 5746      8667         2           NaN            0        6       B
# 5764      5285         0         645.0            6        6       B
# 5792       168         0           NaN            0        0       B
# 6079      9515         5           NaN            1       10       B
# 6293       629         1           NaN            0        0       A
# 6505      5285         0         645.0            6        6       B
# 7080      3369        24        4129.0            0        3       B
# 7601     13670         4           NaN            1       11       B
# 7733      5735         3        1084.0            0        5       B
# 8011      5613         5        1340.0            2        5       B
# 8329     13670         4           NaN            1       11       B
# 8855      1892         0           NaN            0        1       B
# 9520       629         1           NaN            0        0       A
#
#               Price
# 286   234194.837047
# 456   113909.099428
# 511   271919.866048
# 682   185993.474671
# 755   164306.314182
# 1614  169528.896664
# 1728  370148.625285
# 1906  455264.882666
# 2108  117296.173704
# 2325  153946.777452
# 2454  445074.956552
# 2632  624549.354546
# 2702  146950.912410
# 2785   99079.960518
# 2790  340273.238253
# 2831  438708.707579
# 3125  460492.010947
# 3228  200021.835127
# 3240  189244.249909
# 3586   88150.012510
# 3725  179466.094235
# 3956  290354.484070
# 4091  194525.103119
# 5002  315245.521059
# 5033  131742.536281
# 5273  160488.033165
# 5663  212188.959537
# 5695  198450.736353
# 5746  562559.600217
# 5764  367353.574566
# 5792  193130.585871
# 6079  216882.265408
# 6293  133273.635012
# 6505  105539.556275
# 7080  261125.669724
# 7601  261733.472106
# 7733  296165.936689
# 8011  423443.464367
# 8329  244220.621495
# 8855   93218.650461
# 9520  108337.484207

# %% [markdown]
# Переменная KitchenSquare оказывает слабое влияние на целевую переменную, в связи с этим выброс её можно удалить. Однако она может влиять на выбор квартиры клиентом, в связи с этим её выбросы заменим на значения согласно логике:
#
# - для KitchenSquare < 5 = 15% от общей площади квартиры;
# - для KitchenSquare > 25 = 15% от общей площади квартиры.

# %%
train_df['LifeSquare'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
train_df.boxplot(column=['LifeSquare'])
# Out:
# <AxesSubplot:>

# %%
train_df[train_df['LifeSquare'] < 10]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 26     8553         88      3  83.262527    4.769175            1.0     13
# 119    5112          6      2  63.591740    0.795539           10.0     17
# 161    6782         45      1   2.954309    5.257278            1.0      3
# 212    1182         27      1  38.936985    3.064320            0.0     18
# 227    3746         62      1  46.722042    1.944446            1.0     11
# ...     ...        ...    ...        ...         ...            ...    ...
# 9462  10079         59      1  48.232742    3.288779            1.0     15
# 9869   3224         27      0   2.377248    0.873147            0.0      1
# 9912  13523         23      1  52.787090    5.600609            1.0      7
# 9938   2913         34      4  94.888596    2.637095            1.0      4
# 9982  10268         27      1  36.112392    1.855415            1.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 26             1       1977   0.127376         B         B        43
# 119           17       2014   0.243205         B         B         5
# 161            1       1977   0.195781         B         B        23
# 212           19       2017   0.211401         B         B         9
# 227           12       2018   0.072158         B         B         2
# ...          ...        ...        ...       ...       ...       ...
# 9462          17       2017   0.019509         B         B        37
# 9869           0       1977   0.017647         B         B         2
# 9912           1       2015   0.014073         B         B         2
# 9938           1       2018   0.069753         B         B        53
# 9982          16       1977   0.211401         B         B         9
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 26        8429         3           NaN            3        9       B
# 119       1564         0         540.0            0        0       B
# 161       5212         6           NaN            3        2       B
# 212       1892         0           NaN            0        1       B
# 227        629         1           NaN            0        0       A
# ...        ...       ...           ...          ...      ...     ...
# 9462      7687        11         176.0            5        5       B
# 9869       469         0           NaN            0        0       B
# 9912       475         0           NaN            0        0       B
# 9938     13670         4           NaN            1       11       B
# 9982      1892         0           NaN            0        1       B
#
#               Price
# 26    410883.892020
# 119   174741.998061
# 161   438005.182323
# 212    93560.789553
# 227   133721.121715
# ...             ...
# 9462  207086.637307
# 9869  126596.941798
# 9912  104160.492175
# 9938  346949.506507
# 9982   94881.691800
#
# [205 rows x 20 columns]

# %%
train_df[train_df['LifeSquare'] > 200]
# Out:
#          Id DistrictId  Rooms      Square   LifeSquare  KitchenSquare  Floor  \
# 357   14990         23      2   48.449875   263.542023            5.0      6
# 1776  16568         27      4  200.334534   201.627365           25.0      1
# 1906   5548         86      5  275.645294   233.949310           26.0     12
# 5183  15886         85      3   78.059334   461.463623           10.0     12
# 7010   2307        102      1  409.425171   410.639740           10.0      4
# 7644   7917         27      0  212.932358   211.231125            0.0      2
# 8000  16550         27      3   81.694420  7480.592285            1.0      9
# 9229  11602         30      2  641.065186   638.163208           10.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 357            5       1972   0.075779         B         B         6
# 1776           2       2013   0.041116         B         B        53
# 1906          37       2011   0.161976         B         A        31
# 5183          16       1998   0.037178         B         B        52
# 7010           4       2016   0.238617         B         B        26
# 7644           3       2008   0.211401         B         B         9
# 8000          17       2016   0.017647         B         B         2
# 9229          19       2019   0.000078         B         B        22
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 357       1437         3           NaN            0        2       B
# 1776     14892         4           NaN            1        4       B
# 1906      7010         5        4508.0            3        7       B
# 5183     11217         1        2300.0            1        7       B
# 7010      3889         6         705.0            3        6       B
# 7644      1892         0           NaN            0        1       B
# 8000       469         0           NaN            0        0       B
# 9229      6398       141        1046.0            3       23       B
#
#               Price
# 357   141780.231857
# 1776  528560.506016
# 1906  455264.882666
# 5183  394253.299978
# 7010   90470.430830
# 7644  302211.260887
# 8000  217357.492366
# 9229  133529.681562

# %% [markdown]
# Переменная LifeSquare оказывает слабое влияние на целевую переменную, в связи с этим её можно удалить. Однако она может влиять на выбор квартиры клиентом, в связи с этим её выбросы заменим на значения согласно логике:
#
# - для LifeSquare < 10 = 70% от общей площади квартиры;
# - для LifeSquare > 200 = 70% от общей площади квартиры;
# - для LifeSquare >= Square = 70% от общей площади квартиры.

# %%
train_df['HouseFloor'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
train_df.boxplot(column=['HouseFloor'])
# Out:
# <AxesSubplot:>

# %%
train_df[train_df['HouseFloor'] == 0]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 24     4717         27      1  44.203945         NaN            0.0      2
# 152   12947         53      2  56.023342         NaN            0.0     14
# 159   13146         74      1  46.449711         NaN            0.0      6
# 186   12174         62      1  44.954880         NaN            0.0      8
# 229   15661         45      3  81.094925         NaN            0.0     15
# ...     ...        ...    ...        ...         ...            ...    ...
# 9889    629         27      1  42.936726         NaN            0.0      2
# 9931  15686          1      1  47.402412         NaN            0.0     14
# 9940   4711          6      1  41.224117         NaN            0.0      8
# 9950   5383         48      3  98.994911         NaN            0.0      3
# 9996  16265         27      2  64.307686   37.038422            9.0     13
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 24             0       1977   0.072158         B         B         2
# 152            0       1977   0.049637         B         B        34
# 159            0       1977   0.075779         B         B         6
# 186            0       1977   0.072158         B         B         2
# 229            0       1977   0.195781         B         B        23
# ...          ...        ...        ...       ...       ...       ...
# 9889           0       1977   0.011654         B         B         4
# 9931           0       1977   0.007122         B         B         1
# 9940           0       1977   0.243205         B         B         5
# 9950           0       1977   0.041125         B         B        46
# 9996           0       1977   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 24         629         1           NaN            0        0       A
# 152       7759         0         229.0            1        3       B
# 159       1437         3           NaN            0        2       B
# 186        629         1           NaN            0        0       A
# 229       5212         6           NaN            3        2       B
# ...        ...       ...           ...          ...      ...     ...
# 9889       915         0           NaN            0        0       B
# 9931       264         0           NaN            0        1       B
# 9940      1564         0         540.0            0        0       B
# 9950      9515         5           NaN            1       10       B
# 9996       629         1           NaN            0        0       A
#
#               Price
# 24    135466.559958
# 152   247074.564832
# 159   168705.450148
# 186   133773.301722
# 229   442472.456032
# ...             ...
# 9889  129674.841139
# 9931  174740.301224
# 9940  125612.639104
# 9950  418817.004446
# 9996  199715.148807
#
# [269 rows x 20 columns]

# %%
train_df[train_df['HouseFloor'] > 50]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 746    9300         74      2  71.747871   74.579811            9.0      5
# 1678     78         30      2  65.773750   66.811790            1.0      8
# 4657  10806          5      1  51.944588   48.709602            1.0      6
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 746           99       1977   0.075779         B         B         6
# 1678         117       1977   0.000078         B         B        22
# 4657          99       1977   0.150818         B         B        16
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 746       1437         3           NaN            0        2       B
# 1678      6398       141        1046.0            3       23       B
# 4657      3433         4        2643.0            4        5       B
#
#               Price
# 746   243329.912579
# 1678  207248.370520
# 4657  296127.115515

# %% [markdown]
# Переменная HouseFloor оказывает слабое влияние на целевую переменную, но имеет большое количество выбросов, при исправлении которых может усилится влияние. В связи с этим выброс = 0 заменим на значения согласно логике:
#
# - HouseFloor = mean_floor - для квартир с Floor < mean_floor;
# - HouseFloor = Floor - для квартир с Floor > mean_floor.
#
# HouseFloor = mean_floor - для квартир с HouseFloor > 50.

# %%
train_df['HouseYear'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
train_df.boxplot(column=['HouseYear'])
# Out:
# <AxesSubplot:>

# %%
train_df[train_df['HouseYear'] > 2020]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 8828  11607        147      2  44.791836   28.360394            5.0      4
# 9163  10814        109      1  37.265072   20.239714            9.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 8828           9       4968   0.319809         B         B        25
# 9163          12   20052011   0.136330         B         B        30
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 8828      4756        16        2857.0            5        8       B
# 9163      6141        10         262.0            3        6       B
#
#               Price
# 8828  243028.603096
# 9163  254084.534396

# %% [markdown]
# Переменная HouseYear оказывает слабое влияние на целевую переменную, но имеет два выброса, при исправлении которых может усилится влияние. В связи с этим выброс > 2020 заменим на среднее значение года постройки дома без учета этих выбросов.

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# #### Обнаружение выбросов в количественных переменных датасета test_df<a class='anckor' id='test_ejection'>

# %%
test_df.describe().round(3)
# Out:
#           Rooms    Square  LifeSquare  KitchenSquare     Floor  HouseFloor  \
# count  5000.000  5000.000    3959.000       5000.000  5000.000    5000.000
# mean      1.910    56.450      36.159          5.977     8.632      12.601
# std       0.839    19.093      17.825          9.950     5.483       6.789
# min       0.000     1.379       0.333          0.000     1.000       0.000
# 25%       1.000    41.906      23.092          1.000     4.000       9.000
# 50%       2.000    52.921      32.925          6.000     7.000      12.000
# 75%       2.000    66.285      45.174          9.000    12.000      17.000
# max      17.000   223.454     303.071        620.000    78.000      99.000
#
#        HouseYear  Ecology_1  Social_1   Social_2  Social_3  Healthcare_1  \
# count   5000.000   5000.000  5000.000   5000.000  5000.000      2623.000
# mean    1984.393      0.120    24.934   5406.900     8.263      1146.657
# std       18.573      0.120    17.532   4026.615    23.864      1044.746
# min     1908.000      0.000     0.000    168.000     0.000         0.000
# 25%     1973.000      0.020     6.000   1564.000     0.000       325.000
# 50%     1977.000      0.072    25.000   5285.000     2.000       900.000
# 75%     2000.000      0.196    36.000   7287.000     5.000      1548.000
# max     2020.000      0.522    74.000  19083.000   141.000      4849.000
#
#        Helthcare_2   Shops_1
# count     5000.000  5000.000
# mean         1.319     4.243
# std          1.480     4.777
# min          0.000     0.000
# 25%          0.000     1.000
# 50%          1.000     3.000
# 75%          2.000     6.000
# max          6.000    23.000

# %% [markdown]
# Предварительная оценка признаков датасета **test_df** на выбросы с помощью метода describe().
# * Rooms - имеет выброс по минимальному значению, т.к. количество комнат должно быть 1 и более;
# * Square - имеет выброс по минимальному значению, т.к. общая площадь должна быть 10 и более;
# * LifeSquare - имеет выброс по минимальному и максимальному значениям, т.к. жилая площадь должна быть 10 и более и не должна быть больше общей площади;
# * KitchenSquare - имеет выброс по минимальному и максимальному значениям, т.к. площадь кухни должна быть 5 и более и не должна быть больше общей площади;
# * HouseFloor - имеет выброс по минимальному значению, т.к. количество этажей в доме должно быть 1 и более;
# * Floor, HouseYear, Ecology_1, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1 - не имеют выбросы
#
# Проведём более подробную оценку выбросов для признаков: **Rooms, Square, HouseFloor, HouseYear.**
#
# Для признаков: **LifeSquare, KitchenSquare** можно не проводить подробную оценку выбросов, т.к. эти признаки имеют очень слабую корреляцию с целевой переменной и их в дальнейшем мы не будем учитывать.

# %%
test_df['Rooms'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
test_df.boxplot(column='Rooms')
# Out:
# <AxesSubplot:>

# %%
test_df['Rooms'].value_counts()
# Out:
# 2     2030
# 1     1769
# 3     1099
# 4       90
# 5        7
# 6        2
# 0        2
# 17       1
# Name: Rooms, dtype: int64

# %%
test_df[test_df['Rooms'] == 0]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 961    3343         58      0  116.824203  113.692421            0.0      3
# 4179  10729         27      0   76.345154   42.820797           12.0     14
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 961            3       1977   0.437885         B         B        23
# 4179           0       1977   0.017647         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 961       5735         3        1084.0            0        5       B
# 4179       469         0           NaN            0        0       B

# %%
test_df[test_df['Rooms'] > 6]
# Out:
#         Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1981  1435        111     17  52.866108   32.528343            8.0     15
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1981          17       1987   0.093443         B         B        23
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1981      4635         5        3300.0            2        4       B

# %% [markdown]
# Для выбросов переменной Rooms проведём замену по схеме:
#
# - Rooms=0 - Rooms=Square//25;
# - Rooms>6 - Rooms=Square//25.

# %%
test_df['Square'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
test_df.boxplot(column='Square')
# Out:
# <AxesSubplot:>

# %%
test_df[test_df['Square'] < 10]
# Out:
#          Id DistrictId  Rooms    Square  LifeSquare  KitchenSquare  Floor  \
# 131   16401         30      1  2.645046    4.338756            1.0      2
# 571     170          6      2  2.900586   61.468563            1.0     18
# 996    2138         27      1  5.647459    1.501582            1.0      1
# 1672   1420         45      1  1.975769    2.900371            1.0      1
# 2051  10120          6      1  5.100671    3.861780            1.0      3
# 2463   9011         53      1  1.378543    1.353573            1.0      1
# 3608   1165         27      1  2.372101    1.899119            1.0      2
# 4193   7855          6      1  4.967143    2.968086            1.0      3
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 131            1       1977   0.000078         B         B        22
# 571           17       2014   0.243205         B         B         5
# 996            1       1977   0.017647         B         B         2
# 1672           1       1977   0.195781         B         B        23
# 2051           1       1977   0.243205         B         B         5
# 2463           1       1977   0.049637         B         B        34
# 3608          17       1977   0.011654         B         B         4
# 4193           1       2018   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 131       6398       141        1046.0            3       23       B
# 571       1564         0         540.0            0        0       B
# 996        469         0           NaN            0        0       B
# 1672      5212         6           NaN            3        2       B
# 2051      1564         0         540.0            0        0       B
# 2463      7759         0         229.0            1        3       B
# 3608       915         0           NaN            0        0       B
# 4193      1564         0         540.0            0        0       B

# %%
test_df[(test_df['Square'] > 200)]
# Out:
#         Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 956   4058         27      6  223.453690  104.113556           16.0      2
# 4402  1397         76      3  221.138763  118.055344            4.0     32
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 956            2       2017   0.041116         B         B        53
# 4402          48       2011   0.000000         B         B         7
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 956      14892         4           NaN            1        4       B
# 4402      1660        39        1786.0            1        5       B

# %% [markdown]
# Для выбросов переменной Square < 10 проведём замену по схеме:
#
# - Square = среднее значение Square для однотипных квартир.

# %%
test_df['LifeSquare'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
test_df.boxplot(column='LifeSquare')
# Out:
# <AxesSubplot:>

# %%
test_df[test_df['LifeSquare'] < 10]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 17     6791          1      3   72.023277    2.470856            1.0      4
# 31     3340         27      3   69.921936    3.986053            1.0      9
# 131   16401         30      1    2.645046    4.338756            1.0      2
# 135    3798         30      2   39.187588    5.199864            1.0      4
# 265    6428          9      1   43.037262    3.013165            1.0      3
# ...     ...        ...    ...         ...         ...            ...    ...
# 4863   1957          6      2   66.922722    5.230383            1.0      4
# 4887  14015          6      2   65.743439    4.104411            1.0     15
# 4913   7021          1      2   65.607025    2.814241            0.0     16
# 4938  12024         25      1   44.925461    4.259876            1.0     27
# 4963     52          1      3  108.652618    1.694469            1.0     10
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 17            24       1977   0.007122         B         B         1
# 31            17       1977   0.211401         B         B         9
# 131            1       1977   0.000078         B         B        22
# 135            1       1977   0.000078         B         B        22
# 265            1       1977   0.161532         B         B        25
# ...          ...        ...        ...       ...       ...       ...
# 4863          17       2019   0.243205         B         B         5
# 4887          17       1977   0.243205         B         B         5
# 4913          17       1977   0.007122         B         B         1
# 4938           1       2013   0.069753         B         B        53
# 4963          17       1977   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 17         264         0           NaN            0        1       B
# 31        1892         0           NaN            0        1       B
# 131       6398       141        1046.0            3       23       B
# 135       6398       141        1046.0            3       23       B
# 265       5648         1          30.0            2        4       B
# ...        ...       ...           ...          ...      ...     ...
# 4863      1564         0         540.0            0        0       B
# 4887      1564         0         540.0            0        0       B
# 4913       264         0           NaN            0        1       B
# 4938     13670         4           NaN            1       11       B
# 4963       264         0           NaN            0        1       B
#
# [110 rows x 19 columns]

# %%
test_df[test_df['LifeSquare'] > test_df['Square']]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1      5925         62      1   42.493908   42.568134           10.0      7
# 25    14686          1      3   77.229889   79.958687            1.0     18
# 28    10869         23      3   78.001884   82.566322            1.0     21
# 39    16384          1      2   52.773670   52.910721           10.0      6
# 48    15509         27      2   55.439861   57.527245           10.0     15
# ...     ...        ...    ...         ...         ...            ...    ...
# 4898  15984         23      3  104.786354  106.730270            1.0     14
# 4945   9888         45      2   60.501259   60.881119           10.0     24
# 4970  13494        169      1   47.012028   47.372334            8.0      4
# 4979   4821         74      2   82.542503   82.585068            0.0      4
# 4996  16138         38      3   93.698120   94.521461           10.0     21
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1             17       2017   0.072158         B         B         2
# 25            17       1977   0.007122         B         B         1
# 28            25       2015   0.075779         B         B         6
# 39            17       2017   0.007122         B         B         1
# 48            17       2016   0.011654         B         B         4
# ...          ...        ...        ...       ...       ...       ...
# 4898          25       1977   0.075779         B         B         6
# 4945          24       2016   0.195781         B         B        23
# 4970          17       2019   0.178917         B         B        18
# 4979          17       2015   0.309479         B         B        35
# 4996          27       2018   0.060753         B         B        15
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1          629         1           NaN            0        0       A
# 25         264         0           NaN            0        1       B
# 28        1437         3           NaN            0        2       B
# 39         264         0           NaN            0        1       B
# 48         915         0           NaN            0        0       B
# ...        ...       ...           ...          ...      ...     ...
# 4898      1437         3           NaN            0        2       B
# 4945      5212         6           NaN            3        2       B
# 4970      3594         4         192.0            1        5       B
# 4979      7715         4         990.0            0        6       B
# 4996      2787         2         520.0            0        7       B
#
# [241 rows x 19 columns]

# %% [markdown]
# Переменная LifeSquare оказывает слабое влияние на целевую переменную, в связи с этим её можно удалить. Однако она может влиять на выбор квартиры клиентом, в связи с этим её выбросы заменим на значения согласно логике:
#
# - для LifeSquare < 10 = 70% от общей площади квартиры;
# - для LifeSquare >= Square = 70% от общей площади квартиры.

# %%
test_df['KitchenSquare'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
test_df.boxplot(column='KitchenSquare')
# Out:
# <AxesSubplot:>

# %%
test_df[test_df['KitchenSquare'] < 5]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 4       746         74      1  53.837055         NaN            1.0      8
# 11    13270          9      3  80.599472         NaN            1.0      4
# 13    16751         74      1  54.614170         NaN            1.0      8
# 14    11404         27      1  44.415508         NaN            1.0     14
# 16    14925         22      2  61.413582         NaN            1.0     13
# ...     ...        ...    ...        ...         ...            ...    ...
# 4986  10616          1      2  77.463539         NaN            1.0      5
# 4988  11890          1      2  66.683296         NaN            1.0      6
# 4989  13069          1      2  61.747208         NaN            0.0      5
# 4993  14676          6      1  48.435108         NaN            1.0     18
# 4994  13060         25      2  51.144905   48.979538            1.0     18
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 4             17       1977   0.309479         B         B        35
# 11             1       1977   0.161532         B         B        25
# 13            17       1977   0.075779         B         B         6
# 14             1       1977   0.072158         B         B         2
# 16            17       1977   0.118537         B         B        30
# ...          ...        ...        ...       ...       ...       ...
# 4986          16       2017   0.007122         B         B         1
# 4988          17       1977   0.007122         B         B         1
# 4989          17       1977   0.007122         B         B         1
# 4993          25       1977   0.243205         B         B         5
# 4994          25       2015   0.069753         B         B        53
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 4         7715         4         990.0            0        6       B
# 11        5648         1          30.0            2        4       B
# 13        1437         3           NaN            0        2       B
# 14         629         1           NaN            0        0       A
# 16        6207         1        1183.0            1        0       B
# ...        ...       ...           ...          ...      ...     ...
# 4986       264         0           NaN            0        1       B
# 4988       264         0           NaN            0        1       B
# 4989       264         0           NaN            0        1       B
# 4993      1564         0         540.0            0        0       B
# 4994     13670         4           NaN            1       11       B
#
# [1562 rows x 19 columns]

# %%
test_df[test_df['KitchenSquare'] > 25]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 337   10662         29      1   25.956829   17.251768           33.0      5
# 544   12612         27      2   60.988495   33.646725           60.0      5
# 683    1968         27      2  138.039185   92.484100           42.0      3
# 972    5428         27      2   62.326042         NaN           61.0     12
# 1117   3747         23      5  139.045761   89.790276           42.0      1
# 1224   8015         27      1   66.099098   33.639610           62.0      3
# 1762   5254        186      2   88.618126   25.457811           30.0      5
# 1851   2249         62      1   77.157677   78.281761           34.0      5
# 2435   4483         62      1   41.951462   45.672138           41.0     13
# 2557   5199         27      2   59.054989   61.647530           57.0     13
# 2817  13736         27      1  141.540222   91.704803           42.0      3
# 3329   6568         78      1   46.827202   40.227013           40.0      5
# 3332   3194         29      2   43.926987   31.028708           44.0      6
# 3750  14594         11      2   42.795303   24.223770          620.0     11
# 4127   5260         73      3   69.358246   51.247581           65.0      6
# 4227   3341         62      3  112.114021  112.247841          112.0      3
# 4342  12640          6      2   54.629143   31.486307           97.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 337            5       1973   0.069660         B         B        31
# 544           17       2013   0.072158         B         B         2
# 683            3       2016   0.014073         B         B         2
# 972           17       1977   0.072158         B         B         2
# 1117           3       2015   0.014073         B         B         2
# 1224           7       2016   0.014058         B         B         1
# 1762          19       1985   0.007659         B         B        35
# 1851          24       2016   0.072158         B         B         2
# 2435          17       2018   0.072158         B         B         2
# 2557          12       2016   0.211401         B         B         9
# 2817           3       2013   0.014073         B         B         2
# 3329          32       2007   0.219006         B         B        28
# 3332           5       1964   0.086885         B         B        10
# 3750          14       1972   0.038693         B         B        28
# 4127           6       1931   0.042032         B         B        37
# 4227           3       2017   0.072158         B         B         2
# 4342          17       2015   0.243205         B         B         5
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 337       6119         4           NaN            1        2       B
# 544        629         1           NaN            0        0       A
# 683        475         0           NaN            0        0       B
# 972        629         1           NaN            0        0       A
# 1117       475         0           NaN            0        0       B
# 1224       290         0           NaN            0        0       B
# 1762      7077        56        2301.0            3       19       B
# 1851       629         1           NaN            0        0       A
# 2435       629         1           NaN            0        0       A
# 2557      1892         0           NaN            0        1       B
# 2817       475         0           NaN            0        0       B
# 3329      6746         3           NaN            1        4       B
# 3332      2277         2        1547.0            0        0       B
# 3750      6533         1        1015.0            2        5       B
# 4127      6856        84        1940.0            2        5       B
# 4227       629         1           NaN            0        0       A
# 4342      1564         0         540.0            0        0       B

# %% [markdown]
# Переменная KitchenSquare оказывает слабое влияние на целевую переменную, в связи с этим выброс её можно удалить. Однако она может влиять на выбор квартиры клиентом, в связи с этим её выбросы заменим на значения согласно логике:
#
# - для KitchenSquare < 5 = 15% от общей площади квартиры;
# - для KitchenSquare > 25 = 15% от общей площади квартиры.

# %%
test_df['HouseFloor'].hist(bins=100, log=True)
# Out:
# <AxesSubplot:>

# %%
test_df.boxplot(column='HouseFloor')
# Out:
# <AxesSubplot:>

# %%
test_df[test_df['HouseFloor'] == 0]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 52    15989         62      1  47.095406         NaN            0.0      4
# 61    12694         27      3  83.670029   46.358356            0.0      8
# 93     6257         62      1  43.835918         NaN            0.0      9
# 95      902         27      3  99.293190         NaN            0.0      2
# 164    2559         23      2  73.868462         NaN            0.0      9
# ...     ...        ...    ...        ...         ...            ...    ...
# 4816   6187         45      3  79.798210         NaN            0.0     17
# 4817  11475         27      1  53.263561         NaN            0.0      9
# 4928  13900        169      1  48.530247         NaN            0.0      8
# 4951    113         27      2  65.548248   35.071278            0.0     17
# 4978  15243         53      2  56.872925         NaN            0.0     20
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 52             0       1977   0.072158         B         B         2
# 61             0       2015   0.072158         B         B         2
# 93             0       1977   0.072158         B         B         2
# 95             0       1977   0.075424         B         B        11
# 164            0       1977   0.075779         B         B         6
# ...          ...        ...        ...       ...       ...       ...
# 4816           0       1977   0.195781         B         B        23
# 4817           0       1977   0.072158         B         B         2
# 4928           0       1977   0.178917         B         B        18
# 4951           0       1977   0.017647         B         B         2
# 4978           0       1977   0.049637         B         B        34
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 52         629         1           NaN            0        0       A
# 61         629         1           NaN            0        0       A
# 93         629         1           NaN            0        0       A
# 95        3097         0           NaN            0        0       B
# 164       1437         3           NaN            0        2       B
# ...        ...       ...           ...          ...      ...     ...
# 4816      5212         6           NaN            3        2       B
# 4817       629         1           NaN            0        0       A
# 4928      3594         4         192.0            1        5       B
# 4951       469         0           NaN            0        0       B
# 4978      7759         0         229.0            1        3       B
#
# [131 rows x 19 columns]

# %%
test_df[test_df['HouseFloor'] > 50]
# Out:
#         Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 449  15864         27      3  47.722836   47.098812            9.0     18
#
#      HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 449          99       1977   0.072158         B         B         2       629
#
#      Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 449         1           NaN            0        0       A

# %% [markdown]
# Переменная HouseFloor оказывает слабое влияние на целевую переменную, но имеет большое количество выбросов, при исправлении которых может усилится влияние. В связи с этим выброс = 0 заменим на значения согласно логике:
#
# - HouseFloor = mean_floor - для квартир с Floor < mean_floor;
# - HouseFloor = Floor - для квартир с Floor > mean_floor.
#
# HouseFloor = Floor - для квартир с HouseFloor > 50.

# %% [markdown]
# т.к. переменная Floor тесно связана с HouseFloor, то для квартир с Floor > HouseFloor - Floor = HouseFloor.

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Анализ категориальных признаков<a class='anckor' id='cat'>

# %% [markdown]
# #### Поиск и анализ категориальных переменных датасета train_df<a class='anckor' id='train_cat'>|
#
# Для поиска будем использовать созданную мной функцию find_cat

# %%
find_cat(train_df)
# Out:
# Id строка,
# DistrictId строка,
# Ecology_2 строка, мало уникальных значений
# Ecology_3 строка, мало уникальных значений
# Shops_2 строка, мало уникальных значений

# %%
train_df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
train_df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
train_df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %% [markdown]
# В нашем датасете признаки Ecology_2, Ecology_3 и Shops_2 являются категориальными. Для кодирования этих признаков будем использовать **Унитарное кодирование (One Hot Encoding)**

# %% [markdown]
# #### Поиск и анализ категориальных переменных датасета test_df<a class='anckor' id='test_cat'>|
#
# Для поиска будем использовать созданную мной функцию find_cat

# %%
find_cat(test_df)
# Out:
# Id строка,
# DistrictId строка,
# Ecology_2 строка, мало уникальных значений
# Ecology_3 строка, мало уникальных значений
# Shops_2 строка, мало уникальных значений

# %%
test_df['Ecology_2'].value_counts()
# Out:
# B    4952
# A      48
# Name: Ecology_2, dtype: int64

# %%
test_df['Ecology_3'].value_counts()
# Out:
# B    4851
# A     149
# Name: Ecology_3, dtype: int64

# %%
test_df['Shops_2'].value_counts()
# Out:
# B    4588
# A     412
# Name: Shops_2, dtype: int64

# %% [markdown]
# В нашем датасете признаки Ecology_2, Ecology_3 и Shops_2 являются категориальными. Для кодирования этих признаков будем использовать **Унитарное кодирование (One Hot Encoding)**

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ## Предобработка данных<a class='anckor' id='preprocessing'>

# %% [markdown]
# ### Обработка пропусков в датасете train_df<a class='anckor' id='process_train_nulls'>

# %%
train_df[train_df['Healthcare_1'].isnull()]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 0     11809         27      3  115.027313         NaN           10.0      4
# 3      2352          1      1   40.409908         NaN            1.0     10
# 4     13866         94      2   64.285065   38.562515            9.0     16
# 8      9951          1      1   46.887894   44.628132            1.0     12
# 11    16755         88      2   53.975143   34.153584            8.0      2
# ...     ...        ...    ...         ...         ...            ...    ...
# 9993   9289          1      3   84.486076   88.931511            0.0      4
# 9995   1260         61      2   49.090729   33.272625            6.0      3
# 9996  16265         27      2   64.307686   37.038422            9.0     13
# 9997   2795        178      1   29.648056   16.555363            5.0      3
# 9999   7202         94      1   35.815475   22.301367            6.0      9
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0             10       2014   0.075424         B         B        11
# 3             22       1977   0.007122         B         B         1
# 4             16       1972   0.282798         B         B        33
# 8             20       1977   0.007122         B         B         1
# 11            12       1978   0.127376         B         B        43
# ...          ...        ...        ...       ...       ...       ...
# 9993          22       2016   0.007122         B         B         1
# 9995          12       1981   0.300323         B         B        52
# 9996           0       1977   0.072158         B         B         2
# 9997           5       1958   0.460556         B         B        20
# 9999           9       1975   0.127376         B         B        43
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 0         3097         0           NaN            0        0       B
# 3          264         0           NaN            0        1       B
# 4         8667         2           NaN            0        6       B
# 8          264         0           NaN            0        1       B
# 11        8429         3           NaN            3        9       B
# ...        ...       ...           ...          ...      ...     ...
# 9993       264         0           NaN            0        1       B
# 9995     10311         6           NaN            1        9       B
# 9996       629         1           NaN            0        0       A
# 9997      4386        14           NaN            1        5       B
# 9999      8429         3           NaN            3        9       B
#
#               Price
# 0     305018.871089
# 3     168106.007630
# 4     343995.102962
# 8     160400.401732
# 11    253124.005332
# ...             ...
# 9993  264213.558631
# 9995  119367.455796
# 9996  199715.148807
# 9997  165953.912580
# 9999  177685.627486
#
# [4798 rows x 20 columns]

# %% [markdown]
# Находим статистические значения для переменной Healthcare_1

# %%
mean_Healthcare_1 = train_df['Healthcare_1'].mean()
min_Healthcare_1 = train_df['Healthcare_1'].min()
median_Healthcare_1 = train_df['Healthcare_1'].median()
mode_Healthcare_1 = train_df['Healthcare_1'].mode()
min_Healthcare_1, mean_Healthcare_1, median_Healthcare_1, mode_Healthcare_1
# Out:
# (0.0,
#  1142.9044189453125,
#  900.0,
#  0    540.0
#  Name: Healthcare_1, dtype: float32)

# %%
train_df['Healthcare_1'].value_counts()
# Out:
# 540.0     511
# 30.0      348
# 1046.0    245
# 750.0     163
# 229.0     148
#          ...
# 370.0      14
# 32.0       12
# 1815.0     10
# 35.0        2
# 0.0         1
# Name: Healthcare_1, Length: 79, dtype: int64

# %% [markdown]
# Заменим пропуски для признака Healthcare_1 на min значение в датасете

# %%
train_df.loc[train_df['Healthcare_1'].isnull(), 'Healthcare_1'] = min_Healthcare_1
train_df['Healthcare_1'].value_counts()
# Out:
# 0.0       4799
# 540.0      511
# 30.0       348
# 1046.0     245
# 750.0      163
#           ...
# 1786.0      15
# 370.0       14
# 32.0        12
# 1815.0      10
# 35.0         2
# Name: Healthcare_1, Length: 79, dtype: int64

# %%
train_df.isnull().mean() * 100
# Out:
# Id                0.00
# DistrictId        0.00
# Rooms             0.00
# Square            0.00
# LifeSquare       21.13
# KitchenSquare     0.00
# Floor             0.00
# HouseFloor        0.00
# HouseYear         0.00
# Ecology_1         0.00
# Ecology_2         0.00
# Ecology_3         0.00
# Social_1          0.00
# Social_2          0.00
# Social_3          0.00
# Healthcare_1      0.00
# Helthcare_2       0.00
# Shops_1           0.00
# Shops_2           0.00
# Price             0.00
# dtype: float64

# %%
train_df.corr().round(2)
# Out:
#                Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Rooms           1.00    0.66        0.13           0.01  -0.00       -0.03
# Square          0.66    1.00        0.20           0.01   0.11        0.08
# LifeSquare      0.13    0.20        1.00          -0.00   0.02        0.03
# KitchenSquare   0.01    0.01       -0.00           1.00  -0.01        0.00
# Floor          -0.00    0.11        0.02          -0.01   1.00        0.42
# HouseFloor     -0.03    0.08        0.03           0.00   0.42        1.00
# HouseYear      -0.01   -0.01       -0.00           0.00   0.00       -0.00
# Ecology_1      -0.03   -0.06       -0.02          -0.01  -0.02       -0.00
# Social_1        0.08   -0.07       -0.05           0.04  -0.04       -0.02
# Social_2        0.07   -0.04       -0.04           0.04  -0.02        0.01
# Social_3        0.01    0.04        0.01          -0.02  -0.00       -0.01
# Healthcare_1    0.05   -0.04       -0.02           0.01  -0.12       -0.10
# Helthcare_2     0.06   -0.02       -0.02           0.04  -0.07       -0.07
# Shops_1         0.05    0.02       -0.01           0.01   0.02        0.03
# Price           0.55    0.52        0.08           0.03   0.13        0.09
#
#                HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms              -0.01      -0.03      0.08      0.07      0.01
# Square             -0.01      -0.06     -0.07     -0.04      0.04
# LifeSquare         -0.00      -0.02     -0.05     -0.04      0.01
# KitchenSquare       0.00      -0.01      0.04      0.04     -0.02
# Floor               0.00      -0.02     -0.04     -0.02     -0.00
# HouseFloor         -0.00      -0.00     -0.02      0.01     -0.01
# HouseYear           1.00       0.00      0.00      0.00      0.00
# Ecology_1           0.00       1.00      0.03      0.01     -0.12
# Social_1            0.00       0.03      1.00      0.96      0.02
# Social_2            0.00       0.01      0.96      1.00      0.07
# Social_3            0.00      -0.12      0.02      0.07      1.00
# Healthcare_1       -0.00       0.12      0.16      0.11      0.24
# Helthcare_2         0.01       0.03      0.52      0.47      0.29
# Shops_1             0.00      -0.08      0.53      0.56      0.66
# Price               0.00      -0.06      0.26      0.24      0.07
#
#                Healthcare_1  Helthcare_2  Shops_1  Price
# Rooms                  0.05         0.06     0.05   0.55
# Square                -0.04        -0.02     0.02   0.52
# LifeSquare            -0.02        -0.02    -0.01   0.08
# KitchenSquare          0.01         0.04     0.01   0.03
# Floor                 -0.12        -0.07     0.02   0.13
# HouseFloor            -0.10        -0.07     0.03   0.09
# HouseYear             -0.00         0.01     0.00   0.00
# Ecology_1              0.12         0.03    -0.08  -0.06
# Social_1               0.16         0.52     0.53   0.26
# Social_2               0.11         0.47     0.56   0.24
# Social_3               0.24         0.29     0.66   0.07
# Healthcare_1           1.00         0.37     0.15   0.17
# Helthcare_2            0.37         1.00     0.47   0.25
# Shops_1                0.15         0.47     1.00   0.18
# Price                  0.17         0.25     0.18   1.00

# %% [markdown]
# После заполнения пропусков в переменной Healthcare_1 увеличилось её влияние на целевую переменную с 14% до 17%

# %%
# создадим датасет для дальнейшей обработки LifeSquare на пропуски, чтобы в дальнейшем сравнить влияние LifeSquare
train_df_LS = train_df.copy()

# %%
# Находим статистические значения для переменной LifeSquare
mean_LifeSquare = train_df_LS['LifeSquare'].mean()
min_LifeSquare = train_df_LS['LifeSquare'].min()
median_LifeSquare = train_df_LS['LifeSquare'].median()
mode_LifeSquare = train_df_LS['LifeSquare'].mode()
min_LifeSquare, mean_LifeSquare, median_LifeSquare, mode_LifeSquare
# Out:
# (0.37061941623687744,
#  37.19966506958008,
#  32.7812614440918,
#  0    33.859653
#  Name: LifeSquare, dtype: float32)

# %%
train_df_LS1 = train_df_LS.copy()

# %%
train_df_LS1.isnull().mean() * 100
# Out:
# Id                0.00
# DistrictId        0.00
# Rooms             0.00
# Square            0.00
# LifeSquare       21.13
# KitchenSquare     0.00
# Floor             0.00
# HouseFloor        0.00
# HouseYear         0.00
# Ecology_1         0.00
# Ecology_2         0.00
# Ecology_3         0.00
# Social_1          0.00
# Social_2          0.00
# Social_3          0.00
# Healthcare_1      0.00
# Helthcare_2       0.00
# Shops_1           0.00
# Shops_2           0.00
# Price             0.00
# dtype: float64

# %%
train_df_LS1.loc[train_df_LS1['LifeSquare'].isnull(), 'LifeSquare'] = min_LifeSquare

# %%
train_df_LS1.isnull().mean() * 100
# Out:
# Id               0.0
# DistrictId       0.0
# Rooms            0.0
# Square           0.0
# LifeSquare       0.0
# KitchenSquare    0.0
# Floor            0.0
# HouseFloor       0.0
# HouseYear        0.0
# Ecology_1        0.0
# Ecology_2        0.0
# Ecology_3        0.0
# Social_1         0.0
# Social_2         0.0
# Social_3         0.0
# Healthcare_1     0.0
# Helthcare_2      0.0
# Shops_1          0.0
# Shops_2          0.0
# Price            0.0
# dtype: float64

# %%
train_df_LS1.corr().round(2)
# Out:
#                Rooms  Square  LifeSquare  KitchenSquare  Floor  HouseFloor  \
# Rooms           1.00    0.66        0.13           0.01  -0.00       -0.03
# Square          0.66    1.00        0.15           0.01   0.11        0.08
# LifeSquare      0.13    0.15        1.00           0.02  -0.01        0.01
# KitchenSquare   0.01    0.01        0.02           1.00  -0.01        0.00
# Floor          -0.00    0.11       -0.01          -0.01   1.00        0.42
# HouseFloor     -0.03    0.08        0.01           0.00   0.42        1.00
# HouseYear      -0.01   -0.01       -0.00           0.00   0.00       -0.00
# Ecology_1      -0.03   -0.06       -0.01          -0.01  -0.02       -0.00
# Social_1        0.08   -0.07        0.04           0.04  -0.04       -0.02
# Social_2        0.07   -0.04        0.04           0.04  -0.02        0.01
# Social_3        0.01    0.04       -0.00          -0.02  -0.00       -0.01
# Healthcare_1    0.05   -0.04        0.02           0.01  -0.12       -0.10
# Helthcare_2     0.06   -0.02        0.03           0.04  -0.07       -0.07
# Shops_1         0.05    0.02        0.02           0.01   0.02        0.03
# Price           0.55    0.52        0.11           0.03   0.13        0.09
#
#                HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms              -0.01      -0.03      0.08      0.07      0.01
# Square             -0.01      -0.06     -0.07     -0.04      0.04
# LifeSquare         -0.00      -0.01      0.04      0.04     -0.00
# KitchenSquare       0.00      -0.01      0.04      0.04     -0.02
# Floor               0.00      -0.02     -0.04     -0.02     -0.00
# HouseFloor         -0.00      -0.00     -0.02      0.01     -0.01
# HouseYear           1.00       0.00      0.00      0.00      0.00
# Ecology_1           0.00       1.00      0.03      0.01     -0.12
# Social_1            0.00       0.03      1.00      0.96      0.02
# Social_2            0.00       0.01      0.96      1.00      0.07
# Social_3            0.00      -0.12      0.02      0.07      1.00
# Healthcare_1       -0.00       0.12      0.16      0.11      0.24
# Helthcare_2         0.01       0.03      0.52      0.47      0.29
# Shops_1             0.00      -0.08      0.53      0.56      0.66
# Price               0.00      -0.06      0.26      0.24      0.07
#
#                Healthcare_1  Helthcare_2  Shops_1  Price
# Rooms                  0.05         0.06     0.05   0.55
# Square                -0.04        -0.02     0.02   0.52
# LifeSquare             0.02         0.03     0.02   0.11
# KitchenSquare          0.01         0.04     0.01   0.03
# Floor                 -0.12        -0.07     0.02   0.13
# HouseFloor            -0.10        -0.07     0.03   0.09
# HouseYear             -0.00         0.01     0.00   0.00
# Ecology_1              0.12         0.03    -0.08  -0.06
# Social_1               0.16         0.52     0.53   0.26
# Social_2               0.11         0.47     0.56   0.24
# Social_3               0.24         0.29     0.66   0.07
# Healthcare_1           1.00         0.37     0.15   0.17
# Helthcare_2            0.37         1.00     0.47   0.25
# Shops_1                0.15         0.47     1.00   0.18
# Price                  0.17         0.25     0.18   1.00

# %%
# Удаление из датасета признака LifeSquare
train_df = train_df.drop('LifeSquare', axis=1)

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Обработка пропусков в датасете train_df<a class='anckor' id='process_test_nulls'>

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ### Обработка выбросов<a class='anckor' id='process_ejection'>

# %% [markdown]
# **Переменная Rooms**
#
# Для переменной Rooms выброс = 0 заменим на значения согласно логике:
#
# - Rooms = 1 - для Square < 40;
# - Rooms = 2 - для Square >= 40 & Square <= 60;
# - Rooms = 3 - для Square > 60
#
# Выбросы с Rooms > 5 удалим из датасета.

# %%
train_df[(train_df['Rooms'] == 0)]
# Out:
#          Id DistrictId  Rooms      Square  KitchenSquare  Floor  HouseFloor  \
# 2194   3159         88      0   38.697117            9.0      9          16
# 3780   7317         27      0   41.790881            0.0     13           0
# 5894    770         28      0   49.483501            0.0     16           0
# 6401   9443         27      0   87.762616            0.0      5          15
# 7644   7917         27      0  212.932361            0.0      2           3
# 7929    456          6      0   81.491446            0.0      4           0
# 9767  12638         27      0  138.427694            0.0      4           3
# 9869   3224         27      0    2.377248            0.0      1           0
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 2194       1982   0.127376         B         B        43      8429         3
# 3780       1977   0.211401         B         B         9      1892         0
# 5894       2015   0.118537         B         B        30      6207         1
# 6401       1977   0.211401         B         B         9      1892         0
# 7644       2008   0.211401         B         B         9      1892         0
# 7929       1977   0.243205         B         B         5      1564         0
# 9767       2016   0.075424         B         B        11      3097         0
# 9869       1977   0.017647         B         B         2       469         0
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 2194           0.0            3        9       B  158998.110646
# 3780           0.0            0        1       B   98129.976788
# 5894        1183.0            1        0       B  217009.338463
# 6401           0.0            0        1       B  219281.918007
# 7644           0.0            0        1       B  302211.260887
# 7929         540.0            0        0       B  212864.799112
# 9767           0.0            0        0       B  268394.744389
# 9869           0.0            0        0       B  126596.941798
#
#       Healthcare_1_nan
# 2194                 1
# 3780                 1
# 5894                 0
# 6401                 1
# 7644                 1
# 7929                 0
# 9767                 1
# 9869                 1

# %%
train_df.loc[(train_df['Rooms'] == 0) & (train_df['Square'] < 38), 'Rooms'] = 1

# %%
train_df.loc[(train_df['Rooms'] == 0) & (train_df['Square'] < 55), 'Rooms'] = 2

# %%
train_df.loc[(train_df['Rooms'] == 0) & (train_df['Square'] > 55), 'Rooms'] = 3

# %%
train_df[(train_df['Rooms'] == 0)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df[(train_df['Rooms'] > 5)]
# Out:
#          Id DistrictId  Rooms     Square  KitchenSquare  Floor  HouseFloor  \
# 2004   5927         57     10  59.056975           10.0     22          22
# 2728  14865          9     10  60.871266           10.0      3           2
# 6088   8491          1     19  42.006046            7.0     17          17
# 8794  14003         99      6  59.414334            6.0      7           9
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 2004       2002   0.090799         B         B        74     19083         2
# 2728       1994   0.161532         B         B        25      5648         1
# 6088       2014   0.007122         B         B         1       264         0
# 8794       1969   0.033494         B         B        66     10573         1
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 2004           0.0            5       15       B  317265.323792
# 2728          30.0            2        4       B  172329.270863
# 6088           0.0            0        1       B   78364.616704
# 8794        1322.0            3        8       B  229661.964416
#
#       Healthcare_1_nan
# 2004                 1
# 2728                 0
# 6088                 1
# 8794                 0

# %%
# поиск индексов строк, которые удовлетворяют нашему критерию отбора: количество комнат (Rooms) > 5
index_drop = train_df[(train_df['Rooms'] > 5)].index
index_drop
# Out:
# Int64Index([2004, 2728, 6088, 8794], dtype='int64')

# %%
# удаление строк из датасета по найденным индексам
train_df = train_df.drop(index_drop, axis=0)
train_df[(train_df['Rooms'] > 5)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %% [markdown]
# **Переменная Square**
#
# Для переменной Square < 10 заменим на среднее значение Square для однотипных квартир.
#
# Выбросы с Square > 300 удалим из датасета.

# %%
train_df[(train_df['Square'] < 10)]
# Out:
#          Id DistrictId  Rooms    Square  KitchenSquare  Floor  HouseFloor  \
# 161    6782         45      1  2.954309            1.0      3           1
# 328    4504         27      3  4.390331            1.0      8          19
# 1401   9487          5      1  5.129222            1.0      1           1
# 4496  15744         34      1  1.988943            1.0     21           4
# 4800   7657         38      1  4.502784            1.0     28           1
# 5009  11526         27      1  4.633498            1.0     18           1
# 7033   1748         88      2  5.497061            1.0     24          22
# 7470  14786          1      1  1.136859            1.0      3           1
# 8572  10202          6      1  2.596351            1.0      3          25
# 8805  10527         27      1  4.380726            1.0     10          17
# 9067  13265          1      3  4.823679            0.0      6          17
# 9869   3224         27      1  2.377248            0.0      1           0
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 161        1977   0.195781         B         B        23      5212         6
# 328        2016   0.211401         B         B         9      1892         0
# 1401       1977   0.150818         B         B        16      3433         4
# 4496       1977   0.069753         B         B        53     13670         4
# 4800       1977   0.060753         B         B        15      2787         2
# 5009       1977   0.011654         B         B         4       915         0
# 7033       1977   0.127376         B         B        43      8429         3
# 7470       1977   0.007122         B         B         1       264         0
# 8572       2014   0.243205         B         B         5      1564         0
# 8805       2013   0.211401         B         B         9      1892         0
# 9067       1977   0.007122         B         B         1       264         0
# 9869       1977   0.017647         B         B         2       469         0
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 161            0.0            3        2       B  438005.182323
# 328            0.0            0        1       B  161379.067034
# 1401        2643.0            4        5       B  369472.403061
# 4496           0.0            1       11       B  458378.777006
# 4800         520.0            0        7       B  483283.488083
# 5009           0.0            0        0       B  107604.269441
# 7033           0.0            3        9       B  412511.088764
# 7470           0.0            0        1       B  181434.825589
# 8572         540.0            0        0       B  137597.601458
# 8805           0.0            0        1       B   97560.720383
# 9067           0.0            0        1       B  237716.681261
# 9869           0.0            0        0       B  126596.941798
#
#       Healthcare_1_nan
# 161                  1
# 328                  1
# 1401                 0
# 4496                 1
# 4800                 0
# 5009                 1
# 7033                 1
# 7470                 1
# 8572                 0
# 8805                 1
# 9067                 1
# 9869                 1

# %%
# Изменим Square < 10 однокомнатной квартиры на среднию площадь однокомнотной квартиры
train_df.loc[(train_df['Square'] < 10) & (train_df['Rooms'] == 1), 'Square'] = train_df[(train_df['Rooms'] == 1)].Square.mean()

# %%
# Изменим Square < 10 двухкомнатной квартиры на среднию площадь двухкомнотной квартиры
train_df.loc[(train_df['Square'] < 10) & (train_df['Rooms'] == 2), 'Square'] = train_df[(train_df['Rooms'] == 2)].Square.mean()

# %%
# Изменим Square < 10 трехкомнатной квартиры на среднию площадь трехкомнотной квартиры
train_df.loc[(train_df['Square'] < 10) & (train_df['Rooms'] == 3), 'Square'] = train_df[(train_df['Rooms'] == 3)].Square.mean()

# %%
train_df[(train_df['Square'] < 10)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df[(train_df['Square'] > 300)]
# Out:
#          Id DistrictId  Rooms      Square  KitchenSquare  Floor  HouseFloor  \
# 726      28          9      2  604.705972            1.0     17          18
# 7010   2307        102      1  409.425181           10.0      4           4
# 9229  11602         30      2  641.065193           10.0     20          19
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 726        1977   0.161532         B         B        25      5648         1
# 7010       2016   0.238617         B         B        26      3889         6
# 9229       2019   0.000078         B         B        22      6398       141
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 726           30.0            2        4       B  187717.242538
# 7010         705.0            3        6       B   90470.430830
# 9229        1046.0            3       23       B  133529.681562
#
#       Healthcare_1_nan
# 726                  0
# 7010                 0
# 9229                 0

# %%
# поиск индексов строк, которые удовлетворяют нашему критерию отбора: количество комнат (Rooms) > 5
index_drop = train_df[(train_df['Square'] > 300)].index
index_drop
# Out:
# Int64Index([726, 7010, 9229], dtype='int64')

# %%
# удаление строк из датасета по найденным индексам
train_df = train_df.drop(index_drop, axis=0)
train_df[(train_df['Square'] > 300)]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df.describe()
# Out:
#              Rooms       Square  KitchenSquare        Floor   HouseFloor  \
# count  9993.000000  9993.000000    9993.000000  9993.000000  9993.000000
# mean      1.888622    56.221293       6.272291     8.523667    12.609126
# std       0.811684    19.076498      28.570688     5.238112     6.775563
# min       1.000000    13.784865       0.000000     1.000000     0.000000
# 25%       1.000000    41.779591       1.000000     4.000000     9.000000
# 50%       2.000000    52.513850       6.000000     7.000000    13.000000
# 75%       2.000000    65.904217       9.000000    12.000000    17.000000
# max       5.000000   275.645284    2014.000000    42.000000   117.000000
#
#           HouseYear    Ecology_1     Social_1      Social_2     Social_3  \
# count  9.993000e+03  9993.000000  9993.000000   9993.000000  9993.000000
# mean   3.991561e+03     0.118872    24.680376   5350.752627     8.029621
# std    2.005705e+05     0.119044    17.525314   4005.141813    23.802550
# min    1.910000e+03     0.000000     0.000000    168.000000     0.000000
# 25%    1.974000e+03     0.017647     6.000000   1564.000000     0.000000
# 50%    1.977000e+03     0.075424    25.000000   5285.000000     2.000000
# 75%    2.001000e+03     0.195781    36.000000   7227.000000     5.000000
# max    2.005201e+07     0.521867    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1          Price  Healthcare_1_nan
# count   9993.000000  9993.000000  9993.000000    9993.000000       9993.000000
# mean     594.641846     1.318623     4.228160  214167.841034          0.479936
# std      932.350769     1.493296     4.802857   92875.968389          0.499622
# min        0.000000     0.000000     0.000000   59174.778028          0.000000
# 25%        0.000000     0.000000     1.000000  153893.979077          0.000000
# 50%       30.000000     1.000000     3.000000  192302.751941          0.000000
# 75%      990.000000     2.000000     6.000000  249174.529858          1.000000
# max     4849.000000     6.000000    23.000000  633233.466570          1.000000

# %%
train_df.corr()
# Out:
#                      Rooms    Square  KitchenSquare     Floor  HouseFloor  \
# Rooms             1.000000  0.763823       0.004558 -0.006571   -0.034103
# Square            0.763823  1.000000       0.008532  0.118190    0.086429
# KitchenSquare     0.004558  0.008532       1.000000 -0.011419    0.000800
# Floor            -0.006571  0.118190      -0.011419  1.000000    0.418460
# HouseFloor       -0.034103  0.086429       0.000800  0.418460    1.000000
# HouseYear        -0.010957 -0.009925       0.000959  0.000935   -0.000864
# Ecology_1        -0.030212 -0.071335      -0.005616 -0.015674   -0.004059
# Social_1          0.075964 -0.079662       0.043383 -0.045388   -0.020977
# Social_2          0.070922 -0.049646       0.037796 -0.017320    0.006813
# Social_3          0.013882  0.022053      -0.015234 -0.003346   -0.008673
# Healthcare_1      0.051466 -0.048244       0.013807 -0.115044   -0.098865
# Helthcare_2       0.062721 -0.033254       0.043138 -0.066268   -0.068947
# Shops_1           0.052832  0.010275       0.010144  0.023045    0.025766
# Price             0.571835  0.581787       0.028892  0.128905    0.088158
# Healthcare_1_nan -0.042405  0.043308      -0.014021  0.062276    0.031031
#
#                   HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms             -0.010957  -0.030212  0.075964  0.070922  0.013882
# Square            -0.009925  -0.071335 -0.079662 -0.049646  0.022053
# KitchenSquare      0.000959  -0.005616  0.043383  0.037796 -0.015234
# Floor              0.000935  -0.015674 -0.045388 -0.017320 -0.003346
# HouseFloor        -0.000864  -0.004059 -0.020977  0.006813 -0.008673
# HouseYear          1.000000   0.001464  0.003032  0.001975  0.000824
# Ecology_1          0.001464   1.000000  0.026574  0.009385 -0.123759
# Social_1           0.003032   0.026574  1.000000  0.956014  0.023960
# Social_2           0.001975   0.009385  0.956014  1.000000  0.073489
# Social_3           0.000824  -0.123759  0.023960  0.073489  1.000000
# Healthcare_1      -0.003585   0.115630  0.163728  0.109749  0.239938
# Helthcare_2        0.011258   0.030918  0.524214  0.472717  0.286519
# Shops_1            0.003692  -0.076443  0.526392  0.559147  0.661747
# Price              0.004304  -0.058435  0.263018  0.238874  0.075455
# Healthcare_1_nan  -0.009598  -0.232229 -0.213396 -0.147552 -0.224519
#
#                   Healthcare_1  Helthcare_2   Shops_1     Price  \
# Rooms                 0.051466     0.062721  0.052832  0.571835
# Square               -0.048244    -0.033254  0.010275  0.581787
# KitchenSquare         0.013807     0.043138  0.010144  0.028892
# Floor                -0.115044    -0.066268  0.023045  0.128905
# HouseFloor           -0.098865    -0.068947  0.025766  0.088158
# HouseYear            -0.003585     0.011258  0.003692  0.004304
# Ecology_1             0.115630     0.030918 -0.076443 -0.058435
# Social_1              0.163728     0.524214  0.526392  0.263018
# Social_2              0.109749     0.472717  0.559147  0.238874
# Social_3              0.239938     0.286519  0.661747  0.075455
# Healthcare_1          1.000000     0.365800  0.148957  0.173997
# Helthcare_2           0.365800     1.000000  0.473680  0.253168
# Shops_1               0.148957     0.473680  1.000000  0.181151
# Price                 0.173997     0.253168  0.181151  1.000000
# Healthcare_1_nan     -0.612734    -0.404851 -0.184229 -0.148258
#
#                   Healthcare_1_nan
# Rooms                    -0.042405
# Square                    0.043308
# KitchenSquare            -0.014021
# Floor                     0.062276
# HouseFloor                0.031031
# HouseYear                -0.009598
# Ecology_1                -0.232229
# Social_1                 -0.213396
# Social_2                 -0.147552
# Social_3                 -0.224519
# Healthcare_1             -0.612734
# Helthcare_2              -0.404851
# Shops_1                  -0.184229
# Price                    -0.148258
# Healthcare_1_nan          1.000000

# %% [markdown]
# **Переменная KitchenSquare**
#
# Для переменной KitchenSquare выбросы заменим на значения согласно логике:
#
# - для KitchenSquare < 5 = 15% от общей площади квартиры;
# - для KitchenSquare > 30 = 15% от общей площади квартиры.

# %%
train_df[train_df['KitchenSquare'] < 5]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 3      2352          1      1  40.409908         NaN            1.0     10
# 8      9951          1      1  46.887894   44.628132            1.0     12
# 9      8094          6      3  79.867477   75.085129            1.0      3
# 18     4581          1      1  47.582481         NaN            1.0     16
# 19      367         45      1  42.367290   40.012527            1.0     16
# ...     ...        ...    ...        ...         ...            ...    ...
# 9982  10268         27      1  36.112392    1.855415            1.0      9
# 9983    647          1      2  63.324024         NaN            1.0      4
# 9990  10635         21      1  18.983963   11.419796            2.0      1
# 9991  11173          6      2  62.648777         NaN            0.0      6
# 9993   9289          1      3  84.486076   88.931511            0.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 3             22       1977   0.007122         B         B         1
# 8             20       1977   0.007122         B         B         1
# 9             17       2014   0.243205         B         B         5
# 18            16       1977   0.007122         B         B         1
# 19            14       2015   0.195781         B         B        23
# ...          ...        ...        ...       ...       ...       ...
# 9982          16       1977   0.211401         B         B         9
# 9983          17       1977   0.007122         B         B         1
# 9990           5       1967   0.194489         B         B        47
# 9991          17       1977   0.243205         B         B         5
# 9993          22       2016   0.007122         B         B         1
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 3          264         0           NaN            0        1       B
# 8          264         0           NaN            0        1       B
# 9         1564         0         540.0            0        0       B
# 18         264         0           NaN            0        1       B
# 19        5212         6           NaN            3        2       B
# ...        ...       ...           ...          ...      ...     ...
# 9982      1892         0           NaN            0        1       B
# 9983       264         0           NaN            0        1       B
# 9990      8004         3         125.0            3        5       B
# 9991      1564         0         540.0            0        0       B
# 9993       264         0           NaN            0        1       B
#
#               Price
# 3     168106.007630
# 8     160400.401732
# 9     194756.023945
# 18    128803.593810
# 19    250466.980777
# ...             ...
# 9982   94881.691800
# 9983  183809.327114
# 9990  112411.221700
# 9991  182625.548872
# 9993  264213.558631
#
# [3222 rows x 20 columns]

# %%
train_df.loc[(train_df['KitchenSquare'] < 5), 'KitchenSquare'] = train_df['Square'] * 0.15

# %%
train_df[train_df['KitchenSquare'] < 5]
# Out:
#          Id DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 130    8800         23      1  29.706032         NaN       4.455905      5
# 161    6782         45      1   2.954309    5.257278       0.443146      3
# 234    4935         23      1  28.859884         NaN       4.328983     12
# 242    1098        101      1  23.015919   15.739110       3.452388      3
# 299     828         90      1  20.924927   10.651456       3.138739      7
# ...     ...        ...    ...        ...         ...            ...    ...
# 9614   1334         23      1  29.401009         NaN       4.410151      4
# 9631  10476         90      1  21.121279   15.202620       3.168192      4
# 9831  14005         25      1  30.476883   31.817631       4.571533     17
# 9869   3224         27      0   2.377248    0.873147       0.356587      1
# 9990  10635         21      1  18.983963   11.419796       2.847594      1
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 130           12       1977   0.034656         B         B         0
# 161            1       1977   0.195781         B         B        23
# 234           11       1977   0.034656         B         B         0
# 242            5       1967   0.225825         A         B        41
# 299            5       1968   0.265089         B         B        37
# ...          ...        ...        ...       ...       ...       ...
# 9614          17       2019   0.034656         B         B         0
# 9631           5       1964   0.265089         B         B        37
# 9831           1       2015   0.069753         B         B        53
# 9869           0       1977   0.017647         B         B         2
# 9990           5       1967   0.194489         B         B        47
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 130        168         0           NaN            0        0       B
# 161       5212         6           NaN            3        2       B
# 234        168         0           NaN            0        0       B
# 242       6558         7        1548.0            3        2       B
# 299       5288         0        1937.0            3        2       B
# ...        ...       ...           ...          ...      ...     ...
# 9614       168         0           NaN            0        0       B
# 9631      5288         0        1937.0            3        2       B
# 9831     13670         4           NaN            1       11       B
# 9869       469         0           NaN            0        0       B
# 9990      8004         3         125.0            3        5       B
#
#               Price
# 130    60502.583500
# 161   438005.182323
# 234    68375.615508
# 242   132427.987621
# 299   128808.087357
# ...             ...
# 9614   71690.969474
# 9631  113846.123763
# 9831  145436.418642
# 9869  126596.941798
# 9990  112411.221700
#
# [120 rows x 20 columns]

# %%
train_df[train_df['KitchenSquare'] > 30]
# Out:
#          Id DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 286    2737         27      3  123.430069  125.806984     123.000000      5
# 456   10546         62      1   46.013187   43.417042      43.000000      4
# 682   16593         52      2   64.859245         NaN      62.000000     15
# 726      28          9      2  604.705994         NaN      90.705902     17
# 755   15781         10      1   35.813564   19.953993      35.000000      6
# 1614   3267         58      3  138.980820  138.004593      43.000000      2
# 1728  16395          2      3   79.722244   44.731220      72.000000     12
# 2108   2271         27      1   43.292515   42.835644      40.000000     12
# 2325   7111         27      2  139.070297   89.787666      42.000000      5
# 2454  12390         72      3   97.490677   99.323555      96.000000     22
# 2632    300         31      2  106.427689   34.230415      32.000000      4
# 2702   1315          6      1   48.128113   45.023533      48.000000     21
# 2785   6569         27      1   38.220257   18.716856      84.000000      4
# 2790  15947        129      4  185.906403   84.830078      31.000000      5
# 2831  12507         54      2   79.810532   79.578964      78.000000     10
# 3228   6708         48      1   42.069359   22.487740      39.000000      1
# 3240   2371         27      2   68.841072   64.234955      66.000000      4
# 3586  12918         23      2   51.440464   53.134243      51.000000      3
# 3725    299         27      2   66.787521   64.616661      60.000000     14
# 3956   4966         96      3   78.445679   47.146755      75.000000      9
# 4091  15466         88      1   42.357487   44.779713      41.000000     10
# 5002   7441         62      3  114.734474  112.589081     112.000000      3
# 5033  16781         27      1   36.138409   36.710541      36.000000     19
# 5273  13703         42      1   38.071693   19.723547      73.000000      9
# 5663  11739         27      2   61.070297   59.845093      58.000000      8
# 5695  11624         46      1   42.983284   24.224436      37.000000     15
# 5792   6508         23      2   67.146049   33.959152      63.000000      5
# 6079    448         48      1   41.186905    1.626502      41.000000      2
# 6293    673         27      1   54.418213   51.498581      51.000000     10
# 6505  14679         81      1   32.276665   19.278395    1970.000000      6
# 7080   4265        161      2   53.216778   32.644859      53.000000      7
# 7601  12666         34      2   60.603363    2.400832      58.000000     14
# 7644   7917         27      0  212.932358  211.231125      31.939856      2
# 7733  12552         58      3  116.405693  113.109650     112.000000      3
# 8011   3233        129      4  186.692596   87.487083      32.000000      3
# 8329   7162         34      2   56.738762   57.510395      54.000000     26
# 8855   9690         27      1   40.081043   37.834965      37.000000     18
# 9520  14656         62      1   47.100719   46.447960    2014.000000      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 286           10       2015   0.017647         B         B         2
# 456           17       2019   0.072158         B         B         2
# 682           17       1977   0.371149         B         B        34
# 726           18       1977   0.161532         B         B        25
# 755           14       1971   0.282798         B         B        33
# 1614           2       1977   0.437885         B         B        23
# 1728          16       1987   0.130618         B         B        39
# 2108          11       2015   0.211401         B         B         9
# 2325           3       2016   0.014073         B         B         2
# 2454          25       2019   0.210473         B         B        11
# 2632          40       2013   0.151346         B         A        32
# 2702           1       2013   0.243205         B         B         5
# 2785          17       2018   0.011654         B         B         4
# 2790           3       2015   0.020741         B         B        24
# 2831          15       2014   0.006076         B         B        30
# 3228          10       2010   0.041125         B         B        46
# 3240           2       2014   0.017647         B         B         2
# 3586          17       2017   0.005767         B         B         1
# 3725          20       2015   0.017647         B         B         2
# 3956          12       1977   0.041116         B         B        53
# 4091          19       2016   0.127376         B         B        43
# 5002           3       2015   0.072158         B         B         2
# 5033          19       2017   0.072158         B         B         2
# 5273          10       2006   0.158249         B         B        21
# 5663          17       2016   0.072158         B         B         2
# 5695          16       1983   0.188784         B         B        31
# 5792          17       2019   0.034656         B         B         0
# 6079           1       1977   0.041125         B         B        46
# 6293          17       2017   0.072158         B         B         2
# 6505           1       1977   0.006076         B         B        30
# 7080          17       1994   0.000699         B         B        14
# 7601          22       1977   0.069753         B         B        53
# 7644           3       2008   0.211401         B         B         9
# 7733           3       2016   0.437885         B         B        23
# 8011           3       2011   0.020741         B         B        24
# 8329          25       2016   0.069753         B         B        53
# 8855          19       2019   0.211401         B         B         9
# 9520           1       2014   0.072158         B         B         2
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# 286        469         0           NaN            0        0       B
# 456        629         1           NaN            0        0       A
# 682       7065         1         750.0            2        5       B
# 726       5648         1          30.0            2        4       B
# 755       8667         2           NaN            0        6       B
# 1614      5735         3        1084.0            0        5       B
# 1728     10418         9         900.0            1        9       B
# 2108      1892         0           NaN            0        1       B
# 2325       475         0           NaN            0        0       B
# 2454      2398         2        1994.0            3        0       B
# 2632      5889        10         830.0            4        1       B
# 2702      1564         0         540.0            0        0       B
# 2785       915         0           NaN            0        0       B
# 2790      5613         5        1340.0            2        5       B
# 2831      5285         0         645.0            6        6       B
# 3228      9515         5           NaN            1       10       B
# 3240       469         0           NaN            0        0       B
# 3586       388         0           NaN            0        0       B
# 3725       469         0           NaN            0        0       B
# 3956     14892         4           NaN            1        4       B
# 4091      8429         3           NaN            3        9       B
# 5002       629         1           NaN            0        0       A
# 5033       629         1           NaN            0        0       A
# 5273      5731         0           NaN            1        0       B
# 5663       629         1           NaN            0        0       A
# 5695      6137         4           NaN            0        1       B
# 5792       168         0           NaN            0        0       B
# 6079      9515         5           NaN            1       10       B
# 6293       629         1           NaN            0        0       A
# 6505      5285         0         645.0            6        6       B
# 7080      3369        24        4129.0            0        3       B
# 7601     13670         4           NaN            1       11       B
# 7644      1892         0           NaN            0        1       B
# 7733      5735         3        1084.0            0        5       B
# 8011      5613         5        1340.0            2        5       B
# 8329     13670         4           NaN            1       11       B
# 8855      1892         0           NaN            0        1       B
# 9520       629         1           NaN            0        0       A
#
#               Price
# 286   234194.837047
# 456   113909.099428
# 682   185993.474671
# 726   187717.242538
# 755   164306.314182
# 1614  169528.896664
# 1728  370148.625285
# 2108  117296.173704
# 2325  153946.777452
# 2454  445074.956552
# 2632  624549.354546
# 2702  146950.912410
# 2785   99079.960518
# 2790  340273.238253
# 2831  438708.707579
# 3228  200021.835127
# 3240  189244.249909
# 3586   88150.012510
# 3725  179466.094235
# 3956  290354.484070
# 4091  194525.103119
# 5002  315245.521059
# 5033  131742.536281
# 5273  160488.033165
# 5663  212188.959537
# 5695  198450.736353
# 5792  193130.585871
# 6079  216882.265408
# 6293  133273.635012
# 6505  105539.556275
# 7080  261125.669724
# 7601  261733.472106
# 7644  302211.260887
# 7733  296165.936689
# 8011  423443.464367
# 8329  244220.621495
# 8855   93218.650461
# 9520  108337.484207

# %%
train_df.loc[(train_df['KitchenSquare'] > 30), 'KitchenSquare'] = train_df['Square'] * 0.15

# %%
train_df.loc[8011]
# Out:
# Id                        3233
# DistrictId                 129
# Rooms                        4
# Square              186.692596
# LifeSquare           87.487083
# KitchenSquare        28.003891
# Floor                        3
# HouseFloor                   3
# HouseYear                 2011
# Ecology_1             0.020741
# Ecology_2                    B
# Ecology_3                    B
# Social_1                    24
# Social_2                  5613
# Social_3                     5
# Healthcare_1            1340.0
# Helthcare_2                  2
# Shops_1                      5
# Shops_2                      B
# Price            423443.464367
# Name: 8011, dtype: object

# %% [markdown]
# **Переменная HouseFloor**
#
# Для переменная HouseFloor = 0 заменим на значения согласно логике:
#
# - HouseFloor = mean_floor - для квартир с Floor < mean_floor;
# - HouseFloor = Floor - для квартир с Floor > mean_floor.
#
# HouseFloor = mean_floor - для квартир с HouseFloor > 50.

# %%
# среднее значение Floor из выборки с HouseFloor = 0
tr = train_df[train_df['HouseFloor'] == 0]
mean_floor = round(tr['Floor'].mean())
mean_floor
# Out:
# 9

# %%
train_df[train_df['HouseFloor'] == 0]
# Out:
#          Id DistrictId  Rooms     Square  KitchenSquare  Floor  HouseFloor  \
# 24     4717         27      1  44.203947            0.0      2           0
# 152   12947         53      2  56.023342            0.0     14           0
# 159   13146         74      1  46.449711            0.0      6           0
# 186   12174         62      1  44.954880            0.0      8           0
# 229   15661         45      3  81.094922            0.0     15           0
# ...     ...        ...    ...        ...            ...    ...         ...
# 9889    629         27      1  42.936724            0.0      2           0
# 9931  15686          1      1  47.402412            0.0     14           0
# 9940   4711          6      1  41.224118            0.0      8           0
# 9950   5383         48      3  98.994909            0.0      3           0
# 9996  16265         27      2  64.307684            9.0     13           0
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 24         1977   0.072158         B         B         2       629         1
# 152        1977   0.049637         B         B        34      7759         0
# 159        1977   0.075779         B         B         6      1437         3
# 186        1977   0.072158         B         B         2       629         1
# 229        1977   0.195781         B         B        23      5212         6
# ...         ...        ...       ...       ...       ...       ...       ...
# 9889       1977   0.011654         B         B         4       915         0
# 9931       1977   0.007122         B         B         1       264         0
# 9940       1977   0.243205         B         B         5      1564         0
# 9950       1977   0.041125         B         B        46      9515         5
# 9996       1977   0.072158         B         B         2       629         1
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 24             0.0            0        0       A  135466.559958
# 152          229.0            1        3       B  247074.564832
# 159            0.0            0        2       B  168705.450148
# 186            0.0            0        0       A  133773.301722
# 229            0.0            3        2       B  442472.456032
# ...            ...          ...      ...     ...            ...
# 9889           0.0            0        0       B  129674.841139
# 9931           0.0            0        1       B  174740.301224
# 9940         540.0            0        0       B  125612.639104
# 9950           0.0            1       10       B  418817.004446
# 9996           0.0            0        0       A  199715.148807
#
#       Healthcare_1_nan
# 24                   1
# 152                  0
# 159                  1
# 186                  1
# 229                  1
# ...                ...
# 9889                 1
# 9931                 1
# 9940                 0
# 9950                 1
# 9996                 1
#
# [269 rows x 20 columns]

# %%
train_df.loc[(train_df['HouseFloor'] == 0) & (train_df['Floor'] <= mean_floor), 'HouseFloor'] = mean_floor

# %%
train_df.loc[(train_df['HouseFloor'] == 0) & (train_df['Floor'] > mean_floor), 'HouseFloor'] = train_df['Floor']

# %%
train_df[train_df['HouseFloor'] == 0]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df.loc[(train_df['HouseFloor'] > 50), 'HouseFloor'] = mean_floor

# %%
train_df[train_df['HouseFloor'] > 50]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df.describe()
# Out:
#              Rooms       Square  KitchenSquare        Floor   HouseFloor  \
# count  9993.000000  9993.000000    9993.000000  9993.000000  9993.000000
# mean      1.888622    56.221293       6.272291     8.523667    12.881417
# std       0.811684    19.076498      28.570688     5.238112     6.277242
# min       1.000000    13.784865       0.000000     1.000000     1.000000
# 25%       1.000000    41.779591       1.000000     4.000000     9.000000
# 50%       2.000000    52.513850       6.000000     7.000000    14.000000
# 75%       2.000000    65.904217       9.000000    12.000000    17.000000
# max       5.000000   275.645284    2014.000000    42.000000    48.000000
#
#           HouseYear    Ecology_1     Social_1      Social_2     Social_3  \
# count  9.993000e+03  9993.000000  9993.000000   9993.000000  9993.000000
# mean   3.991561e+03     0.118872    24.680376   5350.752627     8.029621
# std    2.005705e+05     0.119044    17.525314   4005.141813    23.802550
# min    1.910000e+03     0.000000     0.000000    168.000000     0.000000
# 25%    1.974000e+03     0.017647     6.000000   1564.000000     0.000000
# 50%    1.977000e+03     0.075424    25.000000   5285.000000     2.000000
# 75%    2.001000e+03     0.195781    36.000000   7227.000000     5.000000
# max    2.005201e+07     0.521867    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1          Price  Healthcare_1_nan
# count   9993.000000  9993.000000  9993.000000    9993.000000       9993.000000
# mean     594.641846     1.318623     4.228160  214167.841034          0.479936
# std      932.350769     1.493296     4.802857   92875.968389          0.499622
# min        0.000000     0.000000     0.000000   59174.778028          0.000000
# 25%        0.000000     0.000000     1.000000  153893.979077          0.000000
# 50%       30.000000     1.000000     3.000000  192302.751941          0.000000
# 75%      990.000000     2.000000     6.000000  249174.529858          1.000000
# max     4849.000000     6.000000    23.000000  633233.466570          1.000000

# %%
train_df.corr()
# Out:
#                      Rooms    Square  KitchenSquare     Floor  HouseFloor  \
# Rooms             1.000000  0.763823       0.004558 -0.006571   -0.037850
# Square            0.763823  1.000000       0.008532  0.118190    0.109507
# KitchenSquare     0.004558  0.008532       1.000000 -0.011419   -0.008512
# Floor            -0.006571  0.118190      -0.011419  1.000000    0.473409
# HouseFloor       -0.037850  0.109507      -0.008512  0.473409    1.000000
# HouseYear        -0.010957 -0.009925       0.000959  0.000935   -0.001368
# Ecology_1        -0.030212 -0.071335      -0.005616 -0.015674   -0.014829
# Social_1          0.075964 -0.079662       0.043383 -0.045388   -0.059114
# Social_2          0.070922 -0.049646       0.037796 -0.017320   -0.025310
# Social_3          0.013882  0.022053      -0.015234 -0.003346   -0.026460
# Healthcare_1      0.051466 -0.048244       0.013807 -0.115044   -0.130298
# Helthcare_2       0.062721 -0.033254       0.043138 -0.066268   -0.101187
# Shops_1           0.052832  0.010275       0.010144  0.023045   -0.001151
# Price             0.571835  0.581787       0.028892  0.128905    0.092271
# Healthcare_1_nan -0.042405  0.043308      -0.014021  0.062276    0.066972
#
#                   HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms             -0.010957  -0.030212  0.075964  0.070922  0.013882
# Square            -0.009925  -0.071335 -0.079662 -0.049646  0.022053
# KitchenSquare      0.000959  -0.005616  0.043383  0.037796 -0.015234
# Floor              0.000935  -0.015674 -0.045388 -0.017320 -0.003346
# HouseFloor        -0.001368  -0.014829 -0.059114 -0.025310 -0.026460
# HouseYear          1.000000   0.001464  0.003032  0.001975  0.000824
# Ecology_1          0.001464   1.000000  0.026574  0.009385 -0.123759
# Social_1           0.003032   0.026574  1.000000  0.956014  0.023960
# Social_2           0.001975   0.009385  0.956014  1.000000  0.073489
# Social_3           0.000824  -0.123759  0.023960  0.073489  1.000000
# Healthcare_1      -0.003585   0.115630  0.163728  0.109749  0.239938
# Helthcare_2        0.011258   0.030918  0.524214  0.472717  0.286519
# Shops_1            0.003692  -0.076443  0.526392  0.559147  0.661747
# Price              0.004304  -0.058435  0.263018  0.238874  0.075455
# Healthcare_1_nan  -0.009598  -0.232229 -0.213396 -0.147552 -0.224519
#
#                   Healthcare_1  Helthcare_2   Shops_1     Price  \
# Rooms                 0.051466     0.062721  0.052832  0.571835
# Square               -0.048244    -0.033254  0.010275  0.581787
# KitchenSquare         0.013807     0.043138  0.010144  0.028892
# Floor                -0.115044    -0.066268  0.023045  0.128905
# HouseFloor           -0.130298    -0.101187 -0.001151  0.092271
# HouseYear            -0.003585     0.011258  0.003692  0.004304
# Ecology_1             0.115630     0.030918 -0.076443 -0.058435
# Social_1              0.163728     0.524214  0.526392  0.263018
# Social_2              0.109749     0.472717  0.559147  0.238874
# Social_3              0.239938     0.286519  0.661747  0.075455
# Healthcare_1          1.000000     0.365800  0.148957  0.173997
# Helthcare_2           0.365800     1.000000  0.473680  0.253168
# Shops_1               0.148957     0.473680  1.000000  0.181151
# Price                 0.173997     0.253168  0.181151  1.000000
# Healthcare_1_nan     -0.612734    -0.404851 -0.184229 -0.148258
#
#                   Healthcare_1_nan
# Rooms                    -0.042405
# Square                    0.043308
# KitchenSquare            -0.014021
# Floor                     0.062276
# HouseFloor                0.066972
# HouseYear                -0.009598
# Ecology_1                -0.232229
# Social_1                 -0.213396
# Social_2                 -0.147552
# Social_3                 -0.224519
# Healthcare_1             -0.612734
# Helthcare_2              -0.404851
# Shops_1                  -0.184229
# Price                    -0.148258
# Healthcare_1_nan          1.000000

# %% [markdown]
# **Переменная HouseYear**
#
# Переменную HouseYear > 2020 заменим на среднее значение года постройки домов без учета этих выбросов.

# %%
train_df[train_df['HouseYear'] > 2020]
# Out:
#          Id DistrictId  Rooms     Square  KitchenSquare  Floor  HouseFloor  \
# 8828  11607        147      2  44.791836            5.0      4           9
# 9163  10814        109      1  37.265070            9.0      9          12
#
#       HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  Social_3  \
# 8828       4968   0.319809         B         B        25      4756        16
# 9163   20052011   0.136330         B         B        30      6141        10
#
#       Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price  \
# 8828        2857.0            5        8       B  243028.603096
# 9163         262.0            3        6       B  254084.534396
#
#       Healthcare_1_nan
# 8828                 0
# 9163                 0

# %%
# Изменим HouseYear > 2020 на среднее значение года постройки домов без учета этих выбросов
train_df.loc[(train_df['HouseYear'] > 2020), 'HouseYear'] = round(train_df[(train_df['HouseYear'] < 2021)].HouseYear.mean())

# %%
train_df[train_df['HouseYear'] > 2020]
# Out:
# Empty DataFrame
# Columns: [Id, DistrictId, Rooms, Square, KitchenSquare, Floor, HouseFloor, HouseYear, Ecology_1, Ecology_2, Ecology_3, Social_1, Social_2, Social_3, Healthcare_1, Helthcare_2, Shops_1, Shops_2, Price, Healthcare_1_nan]
# Index: []

# %%
train_df.describe()
# Out:
#              Rooms       Square  KitchenSquare        Floor   HouseFloor  \
# count  9993.000000  9993.000000    9993.000000  9993.000000  9993.000000
# mean      1.888622    56.221293       6.272291     8.523667    12.881417
# std       0.811684    19.076498      28.570688     5.238112     6.277242
# min       1.000000    13.784865       0.000000     1.000000     1.000000
# 25%       1.000000    41.779591       1.000000     4.000000     9.000000
# 50%       2.000000    52.513850       6.000000     7.000000    14.000000
# 75%       2.000000    65.904217       9.000000    12.000000    17.000000
# max       5.000000   275.645284    2014.000000    42.000000    48.000000
#
#          HouseYear    Ecology_1     Social_1      Social_2     Social_3  \
# count  9993.000000  9993.000000  9993.000000   9993.000000  9993.000000
# mean   1984.855699     0.118872    24.680376   5350.752627     8.029621
# std      18.406103     0.119044    17.525314   4005.141813    23.802550
# min    1910.000000     0.000000     0.000000    168.000000     0.000000
# 25%    1974.000000     0.017647     6.000000   1564.000000     0.000000
# 50%    1977.000000     0.075424    25.000000   5285.000000     2.000000
# 75%    2001.000000     0.195781    36.000000   7227.000000     5.000000
# max    2020.000000     0.521867    74.000000  19083.000000   141.000000
#
#        Healthcare_1  Helthcare_2      Shops_1          Price  Healthcare_1_nan
# count   9993.000000  9993.000000  9993.000000    9993.000000       9993.000000
# mean     594.641846     1.318623     4.228160  214167.841034          0.479936
# std      932.350769     1.493296     4.802857   92875.968389          0.499622
# min        0.000000     0.000000     0.000000   59174.778028          0.000000
# 25%        0.000000     0.000000     1.000000  153893.979077          0.000000
# 50%       30.000000     1.000000     3.000000  192302.751941          0.000000
# 75%      990.000000     2.000000     6.000000  249174.529858          1.000000
# max     4849.000000     6.000000    23.000000  633233.466570          1.000000

# %%
train_df.corr()
# Out:
#                      Rooms    Square  KitchenSquare     Floor  HouseFloor  \
# Rooms             1.000000  0.763823       0.004558 -0.006571   -0.037850
# Square            0.763823  1.000000       0.008532  0.118190    0.109507
# KitchenSquare     0.004558  0.008532       1.000000 -0.011419   -0.008512
# Floor            -0.006571  0.118190      -0.011419  1.000000    0.473409
# HouseFloor       -0.037850  0.109507      -0.008512  0.473409    1.000000
# HouseYear        -0.043171  0.191593       0.038471  0.284190    0.412809
# Ecology_1        -0.030212 -0.071335      -0.005616 -0.015674   -0.014829
# Social_1          0.075964 -0.079662       0.043383 -0.045388   -0.059114
# Social_2          0.070922 -0.049646       0.037796 -0.017320   -0.025310
# Social_3          0.013882  0.022053      -0.015234 -0.003346   -0.026460
# Healthcare_1      0.051466 -0.048244       0.013807 -0.115044   -0.130298
# Helthcare_2       0.062721 -0.033254       0.043138 -0.066268   -0.101187
# Shops_1           0.052832  0.010275       0.010144  0.023045   -0.001151
# Price             0.571835  0.581787       0.028892  0.128905    0.092271
# Healthcare_1_nan -0.042405  0.043308      -0.014021  0.062276    0.066972
#
#                   HouseYear  Ecology_1  Social_1  Social_2  Social_3  \
# Rooms             -0.043171  -0.030212  0.075964  0.070922  0.013882
# Square             0.191593  -0.071335 -0.079662 -0.049646  0.022053
# KitchenSquare      0.038471  -0.005616  0.043383  0.037796 -0.015234
# Floor              0.284190  -0.015674 -0.045388 -0.017320 -0.003346
# HouseFloor         0.412809  -0.014829 -0.059114 -0.025310 -0.026460
# HouseYear          1.000000  -0.066287 -0.047841  0.013650 -0.050445
# Ecology_1         -0.066287   1.000000  0.026574  0.009385 -0.123759
# Social_1          -0.047841   0.026574  1.000000  0.956014  0.023960
# Social_2           0.013650   0.009385  0.956014  1.000000  0.073489
# Social_3          -0.050445  -0.123759  0.023960  0.073489  1.000000
# Healthcare_1      -0.208312   0.115630  0.163728  0.109749  0.239938
# Helthcare_2       -0.116799   0.030918  0.524214  0.472717  0.286519
# Shops_1           -0.002938  -0.076443  0.526392  0.559147  0.661747
# Price              0.037178  -0.058435  0.263018  0.238874  0.075455
# Healthcare_1_nan   0.146473  -0.232229 -0.213396 -0.147552 -0.224519
#
#                   Healthcare_1  Helthcare_2   Shops_1     Price  \
# Rooms                 0.051466     0.062721  0.052832  0.571835
# Square               -0.048244    -0.033254  0.010275  0.581787
# KitchenSquare         0.013807     0.043138  0.010144  0.028892
# Floor                -0.115044    -0.066268  0.023045  0.128905
# HouseFloor           -0.130298    -0.101187 -0.001151  0.092271
# HouseYear            -0.208312    -0.116799 -0.002938  0.037178
# Ecology_1             0.115630     0.030918 -0.076443 -0.058435
# Social_1              0.163728     0.524214  0.526392  0.263018
# Social_2              0.109749     0.472717  0.559147  0.238874
# Social_3              0.239938     0.286519  0.661747  0.075455
# Healthcare_1          1.000000     0.365800  0.148957  0.173997
# Helthcare_2           0.365800     1.000000  0.473680  0.253168
# Shops_1               0.148957     0.473680  1.000000  0.181151
# Price                 0.173997     0.253168  0.181151  1.000000
# Healthcare_1_nan     -0.612734    -0.404851 -0.184229 -0.148258
#
#                   Healthcare_1_nan
# Rooms                    -0.042405
# Square                    0.043308
# KitchenSquare            -0.014021
# Floor                     0.062276
# HouseFloor                0.066972
# HouseYear                 0.146473
# Ecology_1                -0.232229
# Social_1                 -0.213396
# Social_2                 -0.147552
# Social_3                 -0.224519
# Healthcare_1             -0.612734
# Helthcare_2              -0.404851
# Shops_1                  -0.184229
# Price                    -0.148258
# Healthcare_1_nan          1.000000

# %% [markdown]
# [Вернуться к Плану проекта](#plan)
#
# ## Генерация новых признаков<a class='anckor' id='new_cat'>

# %% [markdown]
# ### Кодирование категориальных признаков.

# %% [markdown]
# #### Унитарное кодирование (One Hot Encoding)

# %%
train_df_cod = pd.get_dummies(train_df, columns=["Ecology_2", "Ecology_3", "Shops_2"], prefix=["Ec2", "Ec3", "Sh"])
train_df_cod
# Out:
#          Id DistrictId  Rooms      Square  KitchenSquare  Floor  HouseFloor  \
# 0     11809         27      3  115.027311           10.0      4          10
# 1      3013         22      1   39.832524            8.0      7           8
# 2      8215          1      3   78.342215           10.0      2          17
# 3      2352          1      1   40.409907            1.0     10          22
# 4     13866         94      2   64.285067            9.0     16          16
# ...     ...        ...    ...         ...            ...    ...         ...
# 9995   1260         61      2   49.090728            6.0      3          12
# 9996  16265         27      2   64.307684            9.0     13          13
# 9997   2795        178      1   29.648057            5.0      3           5
# 9998  14561         21      1   32.330292            5.0      3           9
# 9999   7202         94      1   35.815476            6.0      9           9
#
#       HouseYear  Ecology_1  Social_1  ...  Helthcare_2  Shops_1  \
# 0          2014   0.075424        11  ...            0        0
# 1          1966   0.118537        30  ...            1        0
# 2          1988   0.025609        33  ...            3        1
# 3          1977   0.007122         1  ...            0        1
# 4          1972   0.282798        33  ...            0        6
# ...         ...        ...       ...  ...          ...      ...
# 9995       1981   0.300323        52  ...            1        9
# 9996       1977   0.072158         2  ...            0        0
# 9997       1958   0.460556        20  ...            1        5
# 9998       1969   0.194489        47  ...            3        5
# 9999       1975   0.127376        43  ...            3        9
#
#               Price  Healthcare_1_nan  Ec2_A  Ec2_B  Ec3_A  Ec3_B  Sh_A  Sh_B
# 0     305018.871089                 1      0      1      0      1     0     1
# 1     177734.553407                 0      0      1      0      1     0     1
# 2     282078.720850                 0      0      1      0      1     0     1
# 3     168106.007630                 1      0      1      0      1     0     1
# 4     343995.102962                 1      0      1      0      1     0     1
# ...             ...               ...    ...    ...    ...    ...   ...   ...
# 9995  119367.455796                 1      0      1      0      1     0     1
# 9996  199715.148807                 1      0      1      0      1     1     0
# 9997  165953.912580                 1      0      1      0      1     0     1
# 9998  171842.411855                 0      0      1      0      1     0     1
# 9999  177685.627486                 1      0      1      0      1     0     1
#
# [9993 rows x 23 columns]

# %%
train_df_cod.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'KitchenSquare', 'Floor',
#        'HouseFloor', 'HouseYear', 'Ecology_1', 'Social_1', 'Social_2',
#        'Social_3', 'Healthcare_1', 'Helthcare_2', 'Shops_1', 'Price',
#        'Healthcare_1_nan', 'Ec2_A', 'Ec2_B', 'Ec3_A', 'Ec3_B', 'Sh_A', 'Sh_B'],
#       dtype='object')

# %% [markdown]
# [Вернуться к Плану проекта](#plan)

# %% [markdown]
# ### Разделение датасета на train и test<a class='anckor' id='separ'>
#
#     Разделение с помощью: df_train, df_test = df(test_size=0.2, random_state=0)
#     В нашем случае разделение не требуется, т.к. датасет уже разделён.

# %%
# Считываем данные. Перемешиваем строки. 
train_df_cod.sample(frac=1).round(3)
# Out:
#          Id DistrictId  Rooms  Square  KitchenSquare  Floor  HouseFloor  \
# 5755   5172          1      2  64.511            1.0      9          17
# 6297  15229          6      1  62.008            1.0      3           1
# 5257  13455          8      3  79.882            8.0      1           7
# 6025  12437         30      2  55.242            1.0      4           4
# 3388   9849         46      2  44.087            5.0      3           9
# ...     ...        ...    ...     ...            ...    ...         ...
# 214   12216          1      2  67.030            1.0      6          17
# 7140  12511         61      3  67.454            6.0      8          12
# 2483  11419         62      1  36.739            5.0      4           5
# 2719  12781         80      3  61.823            5.0      8           9
# 7856   9859         48      1  40.045            8.0     13          16
#
#       HouseYear  Ecology_1  Social_1  ...  Helthcare_2  Shops_1       Price  \
# 5755       1977      0.007         1  ...            0        1  229102.796
# 6297       1977      0.243         5  ...            0        0  195493.301
# 5257       1998      0.458        26  ...            1        5  258478.477
# 6025       2015      0.000        22  ...            3       23   92135.019
# 3388       1969      0.000        47  ...            3        5  181979.495
# ...         ...        ...       ...  ...          ...      ...         ...
# 214        1977      0.007         1  ...            0        1  204406.328
# 7140       1981      0.300        52  ...            1        9  268959.771
# 2483       1974      0.387         5  ...            0        0  128961.998
# 2719       1977      0.000        39  ...            0        5  233005.926
# 7856       1989      0.041        46  ...            1       10  204988.802
#
#       Healthcare_1_nan  Ec2_A  Ec2_B  Ec3_A  Ec3_B  Sh_A  Sh_B
# 5755                 1      0      1      0      1     0     1
# 6297                 0      0      1      0      1     0     1
# 5257                 0      0      1      1      0     0     1
# 6025                 0      0      1      0      1     0     1
# 3388                 0      0      1      0      1     0     1
# ...                ...    ...    ...    ...    ...   ...   ...
# 214                  1      0      1      0      1     0     1
# 7140                 1      0      1      0      1     0     1
# 2483                 1      0      1      0      1     1     0
# 2719                 0      0      1      0      1     0     1
# 7856                 1      0      1      0      1     0     1
#
# [9993 rows x 23 columns]
